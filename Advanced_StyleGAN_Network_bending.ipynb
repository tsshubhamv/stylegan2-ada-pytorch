# %% [markdown]
# <a href="https://colab.research.google.com/github/dvschultz/stylegan2-ada-pytorch/blob/eps/Advanced_StyleGAN_Network_bending.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Network Bending
# ## Manipulate StyleGAN2 models through rotation, translation, etc.
#
# [Paper](https://arxiv.org/abs/2005.12420) | [Video](https://youtu.be/IlSMQ2RRTh8) | [GitHub](https://github.com/terrybroad/network-bending)
#
# Thanks to [Sid Black](https://twitter.com/realmeatyhuman) for a lot of the code used here.

# %% [markdown]
# ## Install Library
#
# This code uses the PyTorch version of StyleGAN2. Because of that the install process for this may take a couple minutes.

# %%
# !nvidia-smi
# Out:
# Thu Jun 17 00:33:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install libraries
# !git clone -b audio-animate https://github.com/dvschultz/network-bending
# !pip uninstall torch torchvision -y
# !pip install torch==1.5.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install Ninja kmeans-pytorch
# !apt-get install -y vim make gdb libopencv-dev
# !wget https://download.pytorch.org/libtorch/cu101/libtorch-shared-with-deps-1.5.0%2Bcu101.zip
# !unzip /content/libtorch-shared-with-deps-1.5.0+cu101.zip -d /root/
# %cd network-bending

#build custom pytorch transformations
# !chmod +x /content/network-bending/build_custom_transforms.sh
# !/content/network-bending/build_custom_transforms.sh /root/libtorch/
# Out:
# Cloning into 'network-bending'...
# remote: Enumerating objects: 364, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 364 (delta 18), reused 19 (delta 8), pack-reused 332
# Receiving objects: 100% (364/364), 21.44 MiB | 17.74 MiB/s, done.
# Resolving deltas: 100% (209/209), done.
# Uninstalling torch-1.8.1+cu101:
#   Successfully uninstalled torch-1.8.1+cu101
# Uninstalling torchvision-0.9.1+cu101:
#   Successfully uninstalled torchvision-0.9.1+cu101
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.5.0+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.5.0%2Bcu101-cp37-cp37m-linux_x86_64.whl (703.8MB)
#      |████

# %%
def show_local_mp4_video(file_name, width=640, height=640):
  import io
  import base64
  from IPython.display import HTML
  video_encoded = base64.b64encode(io.open(file_name, 'rb').read())
  return HTML(data='''<video width="{0}" height="{1}" alt="test" controls>
                        <source src="data:video/mp4;base64,{2}" type="video/mp4" />
                      </video>'''.format(width, height, video_encoded.decode('ascii')))

# %% [markdown]
# ## Download .pt file
#
# As mentioned above, this library uses the PyTorch version of StyleGAN2. If you have a .pkl file, you’ll need to convert it to a .pt file. I have a notebook to do that here.

# %%
# !gdown --id 1rL-J63eFfn80IYU2GfVY977GI2qOG6dw -O /content/ladiesblack.pt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rL-J63eFfn80IYU2GfVY977GI2qOG6dw
# To: /content/ladiesblack.pt
# 133MB [00:01, 84.2MB/s]

# %% [markdown]
# ## Generate Image Samples (and Latent Vectors)
#
# This script will generate "normal" images because the transform config is blank. I recommend doing this initially so you know what images you want to work with.

# %%
# !python generate.py --ckpt /content/ladiesblack.pt --pics 400 --config /content/network-bending/configs/empty_transform_config.yaml --save_latent=1

# %%
# !zip -r samples-ladiesblack-400.zip ./sample

# %% [markdown]
# If we want to generate images using transformations we have to create a config file, update its values and then run the `generate.py` script using the same config.
#
# Note: order of transforms does matter!

# %%
# !cp ./configs/empty_transform_config.yaml ./configs/custom_transform_config.yaml

# %%
# %%writefile ./configs/custom_transform_config.yaml
# transforms:
# - layer: 1
#   transform: "rotate"
#   params: [45.0]
#   features: "all"
# - layer: 3
#   transform: "translate"
#   params: [-0.5, 0.0] #range is -1 to 1
#   features: "all"
# - layer: 8
#   transform: "scale"
#   params: [1.5]
#   features: "all"
# Out:
# Overwriting ./configs/custom_transform_config.yaml

# %%
# !python generate.py --help

# %%
# !python generate.py --ckpt /content/ladiesblack.pt --pics 10 --config ./configs/custom_transform_config.yaml --dir '/content/custom-samples/'

# %% [markdown]
# You can also generate strips of images where the transform is applied to every single layer insequence. Note this requires a separate transformation config file as well.

# %%
# !cp ./configs/sample_strip_config.yaml ./configs/custom_strip_config.yaml

# %%
# %%writefile ./configs/custom_strip_config.yaml
# transform: "rotate"
# params: [45.0]
# features: "all"
# feature-param:
# Out:
# Overwriting ./configs/custom_strip_config.yaml

# %%
# !python generate_sample_strips.py \
--ckpt /content/ladiesblack.pt \
--pics 30 \
--config ./configs/custom_strip_config.yaml   \
--dir '/content/strips/'
# Out:
# 100% 30/30 [04:08<00:00,  8.29s/it]

# %% [markdown]
# ## Animating Vectors: Script version
#
# You can use a script based version if you want to create interpolations with single transformations.
#
# *   `--num_frames`: how many frames to produce (this value/fps in video = length of animation)
# *   `--transform`: transform function you want to use
# *   `--init_val`, `--end_val`: starting and stoppping points for linear transformation over the total frames
# * `--layer_id`: which of the StyleGAN layers to apply the transformation to. Lower IDs will affect more of the structure, higher IDs will affect more of the details.
# * `--interpolate_ids`: which of the StyleGAN layers to
#
# apply the transformation to. Lower IDs will affect more of the structure, higher IDs will affect more of the details.

# %%
# !python animate.py --ckpt /content/ladiesblack.pt --load_latent /content/network-bending/sample/latents.yaml --latent_id 414 --num_frames 720 --transform "scale" --init_val 0.0 --end_val 2.0 --layer_id=3 --truncation=0.7 --interpolate_ids=1,4,19,24,11,1 --dir="ladiesblack-scale-test"

# %%
show_local_mp4_video('/content/network-bending/ladiescrop28-rotate-layer3.mp4', width=720, height=720)

# %% [markdown]
# ### Multiple Transforms

# %%
# !python animate.py \
--ckpt /content/ladiesblack.pt \
--load_latent /content/network-bending/sample/latents.yaml \
--latent_id 414 \
--num_frames 240 \
--transform "scale,rotate" \
--init_val 0.0,0.0 \
--end_val 2.0,360.0 \
--layer_id 3,1 \
--truncation=0.5 \
--interpolate_ids=1,4,11,1 \
--dir="ladiesblack-multi-test"
# Out:
# [0.0, 0.0]
# 2
#   0% 0/240 [00:00<?, ?it/s]animating frame: 0 , param: 0.008333333333333333
# animating frame: 0 , param: 1.5
# 80 0/4 0.0
#   0% 1/240 [00:00<03:08,  1.27it/s]animating frame: 1 , param: 0.016666666666666666
# animating frame: 1 , param: 3.0
# 80 0/4 0.0125
#   1% 2/240 [00:01<03:00,  1.32it/s]animating frame: 2 , param: 0.025
# animating frame: 2 , param: 4.5
# 80 0/4 0.025
#   1% 3/240 [00:02<02:55,  1.35it/s]animating frame: 3 , param: 0.03333333333333333
# animating frame: 3 , param: 6.0
# 80 0/4 0.0375
#   2% 4/240 [00:02<02:50,  1.39it/s]animating frame: 4 , param: 0.041666666666666664
# animating frame: 4 , param: 7.5
# 80 0/4 0.05
#   2% 5/240 [00:03<02:46,  1.41it/s]animating frame: 5 , param: 0.05
# animating frame: 5 , param: 9.0
# 80 0/4 0.0625
#   2% 6/240 [00:04<02:44,  1.43it/s]animating frame: 6 , param: 0.058333333333333334
# animating frame: 6 , param: 10.5
# 80 0/4 0.075
#   3% 7/240 [00:04<02:41,  1.44it/s]animating frame: 7 , param: 0.06666666666666667
# animating frame: 7 , param: 12.0
# 80 0/4 0.0875
#   3% 8/240 [00:05<02:39,  1.45it/s]animating frame: 8 , param: 0.075
# animating frame: 8 , param: 13.5
# 80 0/4 0.1
#   4% 9/240 [00:06<02:38,  1.46it/s]animating frame: 9 , param: 0.08333333333333333
# animating frame: 9 , param: 15.0
# 80 0/4 0.1125
#   4% 10/240 [00:06<02:37,  1.46it/s]animating frame: 10 , param: 0.09166666666666666
# animating frame: 10 , param: 16.5
# 80 0/4 0.125
#   5% 11/240 [00:07<02:36,  1.46it/s]animating frame: 11 , param: 0.1
# animating frame: 11 , param: 18.0
# 80 0/4 0.1375
#   5% 12/240 [00:08<02:35,  1.47it/s]animating frame: 12 , param: 0.10833333333333334
# animating frame: 12 , param: 19.5
# 80 0/4 0.15
#   5% 13/240 [00:08<02:34,  1.47it/s]animating frame: 13 , param: 0.11666666666666667
# animating frame: 13 , param: 21.0
# 80 0/4 0.1625
#   6% 14/240 [00:09<02:34,  1.47it/s]animating frame: 14 , param: 0.125
# animating frame: 14 , param: 22.5
# 80 0/4 0.175
#   6% 15/240 [00:10<02:32,  1.47it/s]animating frame: 15 , param: 0.13333333333333333
# animating frame: 15 , param: 24.0
# 80 0/4 0.1875
#   7% 16/240 [00:11<02:32,  1.47it/s]animating frame: 16 , param: 0.14166666666666666
# animating frame: 16 , param: 25.5
# 80 0/4 0.2
#   7% 17/240 [00:11<02:31,  1.47it/s]animating frame: 17 , param: 0.15
# animating frame: 17 , param: 27.0
# 80 0/4 0.2125
#   8% 18/240 [00:12<02:30,  1.47it/s]animating frame: 18 , param: 0.15833333333333333
# animating frame: 18 , param: 28.5
# 80 0/4 0.225
#   8% 19/240 [00:13<02:30,  1.47it/s]animating frame: 19 , param: 0.16666666666666666
# animating frame: 19 , param: 30.0
# 80 0/4 0.2375
#   8% 20/240 [00:13<02:29,  1.47it/s]animating frame: 20 , param: 0.175
# animating frame: 20 , param: 31.5
# 80 0/4 0.25
#   9% 21/240 [00:14<02:30,  1.45it/s]animating frame: 21 , param: 0.18333333333333332
# animating frame: 21 , param: 33.0
# 80 0/4 0.2625
#   9% 22/240 [00:15<02:29,  1.46it/s]animating frame: 22 , param: 0.19166666666666665
# animating frame: 22 , param: 34.5
# 80 0/4 0.275
#  10% 23/240 [00:15<02:28,  1.46it/s]animating frame: 23 , param: 0.2
# animating frame: 23 , param: 36.0
# 80 0/4 0.2875
#  10% 24/240 [00:16<02:27,  1.46it/s]animating frame: 24 , param: 0.20833333333333334
# animating frame: 24 , param: 37.5
# 80 0/4 0.3
#  10% 25/240 [00:17<02:26,  1.47it/s]animating frame: 25 , param: 0.21666666666666667
# animating frame: 25 , param: 39.0
# 80 0/4 0.3125
#  11% 26/240 [00:17<02:26,  1.46it/s]animating frame: 26 , param: 0.225
# animating frame: 26 , param: 40.5
# 80 0/4 0.325
#  11% 27/240 [00:18<02:25,  1.46it/s]animating frame: 27 , param: 0.23333333333333334
# animating frame: 27 , param: 42.0
# 80 0/4 0.3375
#  12% 28/240 [00:19<02:24,  1.46it/s]animating frame: 28 , param: 0.24166666666666667
# animating frame: 28 , param: 43.5
# 80 0/4 0.35
#  12% 29/240 [00:19<02:26,  1.44it/s]animating frame: 29 , param: 0.25
# animating frame: 29 , param: 45.0
# 80 0/4 0.3625
#  12% 30/240 [00:20<02:24,  1.45it/s]animating frame: 30 , param: 0.2583333333333333
# animating frame: 30 , param: 46.5
# 80 0/4 0.375
#  13% 31/240 [00:21<02:23,  1.45it/s]animating frame: 31 , param: 0.26666666666666666
# animating frame: 31 , param: 48.0
# 80 0/4 0.3875
#  13% 32/240 [00:21<02:22,  1.46it/s]animating frame: 32 , param: 0.275
# animating frame: 32 , param: 49.5
# 80 0/4 0.4
#  14% 33/240 [00:22<02:22,  1.45it/s]animating frame: 33 , param: 0.2833333333333333
# animating frame: 33 , param: 51.0
# 80 0/4 0.4125
#  14% 34/240 [00:23<02:21,  1.46it/s]animating frame: 34 , param: 0.2916666666666667
# animating frame: 34 , param: 52.5
# 80 0/4 0.425
#  15% 35/240 [00:24<02:19,  1.47it/s]animating frame: 35 , param: 0.3
# animating frame: 35 , param: 54.0
# 80 0/4 0.4375
#  15% 36/240 [00:24<02:18,  1.47it/s]animating frame: 36 , param: 0.30833333333333335
# animating frame: 36 , param: 55.5
# 80 0/4 0.45
#  15% 37/240 [00:25<02:17,  1.48it/s]animating frame: 37 , param: 0.31666666666666665
# animating frame: 37 , param: 57.0
# 80 0/4 0.4625
#  16% 38/240 [00:26<02:16,  1.48it/s]animating frame: 38 , param: 0.325
# animating frame: 38 , param: 58.5
# 80 0/4 0.475
#  16% 39/240 [00:26<02:15,  1.48it/s]animating frame: 39 , param: 0.3333333333333333
# animating frame: 39 , param: 60.0
# 80 0/4 0.4875
#  17% 40/240 [00:27<02:14,  1.49it/s]animating frame: 40 , param: 0.3416666666666667
# animating frame: 40 , param: 61.5
# 80 0/4 0.5
#  17% 41/240 [00:28<02:13,  1.49it/s]animating frame: 41 , param: 0.35
# animating frame: 41 , param: 63.0
# 80 0/4 0.5125
#  18% 42/240 [00:28<02:12,  1.49it/s]animating frame: 42 , param: 0.35833333333333334
# animating frame: 42 , param: 64.5
# 80 0/4 0.525
#  18% 43/240 [00:29<02:12,  1.49it/s]animating frame: 43 , param: 0.36666666666666664
# animating frame: 43 , param: 66.0
# 80 0/4 0.5375
#  18% 44/240 [00:30<02:11,  1.49it/s]animating frame: 44 , param: 0.375
# animating frame: 44 , param: 67.5
# 80 0/4 0.55
#  19% 45/240 [00:30<02:10,  1.49it/s]animating frame: 45 , param: 0.3833333333333333
# animating frame: 45 , param: 69.0
# 80 0/4 0.5625
#  19% 46/240 [00:31<02:10,  1.49it/s]animating frame: 46 , param: 0.39166666666666666
# animating frame: 46 , param: 70.5
# 80 0/4 0.575
#  20% 47/240 [00:32<02:09,  1.49it/s]animating frame: 47 , param: 0.4
# animating frame: 47 , param: 72.0
# 80 0/4 0.5875
#  20% 48/240 [00:32<02:08,  1.50it/s]animating frame: 48 , param: 0.4083333333333333
# animating frame: 48 , param: 73.5
# 80 0/4 0.6
#  20% 49/240 [00:33<02:07,  1.50it/s]animating frame: 49 , param: 0.4166666666666667
# animating frame: 49 , param: 75.0
# 80 0/4 0.6125
#  21% 50/240 [00:34<02:06,  1.50it/s]animating frame: 50 , param: 0.425
# animating frame: 50 , param: 76.5
# 80 0/4 0.625
#  21% 51/240 [00:34<02:05,  1.50it/s]animating frame: 51 , param: 0.43333333333333335
# animating frame: 51 , param: 78.0
# 80 0/4 0.6375
#  22% 52/240 [00:35<02:05,  1.49it/s]animating frame: 52 , param: 0.44166666666666665
# animating frame: 52 , param: 79.5
# 80 0/4 0.65
#  22% 53/240 [00:36<02:05,  1.49it/s]animating frame: 53 , param: 0.45
# animating frame: 53 , param: 81.0
# 80 0/4 0.6625
#  22% 54/240 [00:36<02:04,  1.49it/s]animating frame: 54 , param: 0.4583333333333333
# animating frame: 54 , param: 82.5
# 80 0/4 0.675
#  23% 55/240 [00:37<02:04,  1.49it/s]animating frame: 55 , param: 0.4666666666666667
# animating frame: 55 , param: 84.0
# 80 0/4 0.6875
#  23% 56/240 [00:38<02:03,  1.49it/s]animating frame: 56 , param: 0.475
# animating frame: 56 , param: 85.5
# 80 0/4 0.7
#  24% 57/240 [00:38<02:02,  1.50it/s]animating frame: 57 , param: 0.48333333333333334
# animating frame: 57 , param: 87.0
# 80 0/4 0.7125
#  24% 58/240 [00:39<02:01,  1.50it/s]animating frame: 58 , param: 0.49166666666666664
# animating frame: 58 , param: 88.5
# 80 0/4 0.725
#  25% 59/240 [00:40<02:00,  1.50it/s]animating frame: 59 , param: 0.5
# animating frame: 59 , param: 90.0
# 80 0/4 0.7375
#  25% 60/240 [00:40<01:59,  1.50it/s]animating frame: 60 , param: 0.5083333333333333
# animating frame: 60 , param: 91.5
# 80 0/4 0.75
#  25% 61/240 [00:41<01:58,  1.51it/s]animating frame: 61 , param: 0.5166666666666666
# animating frame: 61 , param: 93.0
# 80 0/4 0.7625
#  26% 62/240 [00:42<01:58,  1.51it/s]animating frame: 62 , param: 0.525
# animating frame: 62 , param: 94.5
# 80 0/4 0.775
#  26% 63/240 [00:42<01:57,  1.51it/s]animating frame: 63 , param: 0.5333333333333333
# animating frame: 63 , param: 96.0
# 80 0/4 0.7875
#  27% 64/240 [00:43<01:56,  1.51it/s]animating frame: 64 , param: 0.5416666666666666
# animating frame: 64 , param: 97.5
# 80 0/4 0.8
#  27% 65/240 [00:44<01:55,  1.52it/s]animating frame: 65 , param: 0.55
# animating frame: 65 , param: 99.0
# 80 0/4 0.8125
#  28% 66/240 [00:44<01:54,  1.52it/s]animating frame: 66 , param: 0.5583333333333333
# animating frame: 66 , param: 100.5
# 80 0/4 0.825
#  28% 67/240 [00:45<01:54,  1.51it/s]animating frame: 67 , param: 0.5666666666666667
# animating frame: 67 , param: 102.0
# 80 0/4 0.8375
#  28% 68/240 [00:46<01:53,  1.51it/s]animating frame: 68 , param: 0.575
# animating frame: 68 , param: 103.5
# 80 0/4 0.85
#  29% 69/240 [00:46<01:52,  1.51it/s]animating frame: 69 , param: 0.5833333333333334
# animating frame: 69 , param: 105.0
# 80 0/4 0.8625
#  29% 70/240 [00:47<01:52,  1.52it/s]animating frame: 70 , param: 0.5916666666666667
# animating frame: 70 , param: 106.5
# 80 0/4 0.875
#  30% 71/240 [00:47<01:51,  1.52it/s]animating frame: 71 , param: 0.6
# animating frame: 71 , param: 108.0
# 80 0/4 0.8875
#  30% 72/240 [00:48<01:51,  1.51it/s]animating frame: 72 , param: 0.6083333333333333
# animating frame: 72 , param: 109.5
# 80 0/4 0.9
#  30% 73/240 [00:49<01:50,  1.52it/s]animating frame: 73 , param: 0.6166666666666667
# animating frame: 73 , param: 111.0
# 80 0/4 0.9125
#  31% 74/240 [00:49<01:50,  1.51it/s]animating frame: 74 , param: 0.625
# animating frame: 74 , param: 112.5
# 80 0/4 0.925
#  31% 75/240 [00:50<01:50,  1.50it/s]animating frame: 75 , param: 0.6333333333333333
# animating frame: 75 , param: 114.0
# 80 0/4 0.9375
#  32% 76/240 [00:51<01:48,  1.51it/s]animating frame: 76 , param: 0.6416666666666666
# animating frame: 76 , param: 115.5
# 80 0/4 0.95
#  32% 77/240 [00:51<01:47,  1.52it/s]animating frame: 77 , param: 0.65
# animating frame: 77 , param: 117.0
# 80 0/4 0.9625
#  32% 78/240 [00:52<01:46,  1.52it/s]animating frame: 78 , param: 0.6583333333333333
# animating frame: 78 , param: 118.5
# 80 0/4 0.975
#  33% 79/240 [00:53<01:45,  1.52it/s]animating frame: 79 , param: 0.6666666666666666
# animating frame: 79 , param: 120.0
# 80 0/4 0.9875
#  33% 80/240 [00:53<01:44,  1.53it/s]animating frame: 80 , param: 0.675
# animating frame: 80 , param: 121.5
# 80 1/4 0.0
#  34% 81/240 [00:54<01:44,  1.53it/s]animating frame: 81 , param: 0.6833333333333333
# animating frame: 81 , param: 123.0
# 80 1/4 0.0125
#  34% 82/240 [00:55<01:44,  1.51it/s]animating frame: 82 , param: 0.6916666666666667
# animating frame: 82 , param: 124.5
# 80 1/4 0.025
#  35% 83/240 [00:55<01:44,  1.50it/s]animating frame: 83 , param: 0.7
# animating frame: 83 , param: 126.0
# 80 1/4 0.0375
#  35% 84/240 [00:56<01:43,  1.51it/s]animating frame: 84 , param: 0.7083333333333334
# animating frame: 84 , param: 127.5
# 80 1/4 0.05
#  35% 85/240 [00:57<01:42,  1.51it/s]animating frame: 85 , param: 0.7166666666666667
# animating frame: 85 , param: 129.0
# 80 1/4 0.0625
#  36% 86/240 [00:57<01:40,  1.52it/s]animating frame: 86 , param: 0.725
# animating frame: 86 , param: 130.5
# 80 1/4 0.075
#  36% 87/240 [00:58<01:40,  1.53it/s]animating frame: 87 , param: 0.7333333333333333
# animating frame: 87 , param: 132.0
# 80 1/4 0.0875
#  37% 88/240 [00:59<01:39,  1.53it/s]animating frame: 88 , param: 0.7416666666666667
# animating frame: 88 , param: 133.5
# 80 1/4 0.1
#  37% 89/240 [00:59<01:37,  1.54it/s]animating frame: 89 , param: 0.75
# animating frame: 89 , param: 135.0
# 80 1/4 0.1125
#  38% 90/240 [01:00<01:37,  1.55it/s]animating frame: 90 , param: 0.7583333333333333
# animating frame: 90 , param: 136.5
# 80 1/4 0.125
#  38% 91/240 [01:01<01:36,  1.55it/s]animating frame: 91 , param: 0.7666666666666666
# animating frame: 91 , param: 138.0
# 80 1/4 0.1375
#  38% 92/240 [01:01<01:35,  1.55it/s]animating frame: 92 , param: 0.775
# animating frame: 92 , param: 139.5
# 80 1/4 0.15
#  39% 93/240 [01:02<01:35,  1.54it/s]animating frame: 93 , param: 0.7833333333333333
# animating frame: 93 , param: 141.0
# 80 1/4 0.1625
#  39% 94/240 [01:03<01:34,  1.55it/s]animating frame: 94 , param: 0.7916666666666666
# animating frame: 94 , param: 142.5
# 80 1/4 0.175
#  40% 95/240 [01:03<01:33,  1.55it/s]animating frame: 95 , param: 0.8
# animating frame: 95 , param: 144.0
# 80 1/4 0.1875
#  40% 96/240 [01:04<01:32,  1.56it/s]animating frame: 96 , param: 0.8083333333333333
# animating frame: 96 , param: 145.5
# 80 1/4 0.2
#  40% 97/240 [01:04<01:31,  1.56it/s]animating frame: 97 , param: 0.8166666666666667
# animating frame: 97 , param: 147.0
# 80 1/4 0.2125
#  41% 98/240 [01:05<01:30,  1.56it/s]animating frame: 98 , param: 0.825
# animating frame: 98 , param: 148.5
# 80 1/4 0.225
#  41% 99/240 [01:06<01:31,  1.54it/s]animating frame: 99 , param: 0.8333333333333334
# animating frame: 99 , param: 150.0
# 80 1/4 0.2375
#  42% 100/240 [01:06<01:30,  1.55it/s]animating frame: 100 , param: 0.8416666666666667
# animating frame: 100 , param: 151.5
# 80 1/4 0.25
#  42% 101/240 [01:07<01:29,  1.55it/s]animating frame: 101 , param: 0.85
# animating frame: 101 , param: 153.0
# 80 1/4 0.2625
#  42% 102/240 [01:08<01:28,  1.56it/s]animating frame: 102 , param: 0.8583333333333333
# animating frame: 102 , param: 154.5
# 80 1/4 0.275
#  43% 103/240 [01:08<01:28,  1.55it/s]animating frame: 103 , param: 0.8666666666666667
# animating frame: 103 , param: 156.0
# 80 1/4 0.2875
#  43% 104/240 [01:09<01:27,  1.56it/s]animating frame: 104 , param: 0.875
# animating frame: 104 , param: 157.5
# 80 1/4 0.3
#  44% 105/240 [01:10<01:26,  1.57it/s]animating frame: 105 , param: 0.8833333333333333
# animating frame: 105 , param: 159.0
# 80 1/4 0.3125
#  44% 106/240 [01:10<01:25,  1.57it/s]animating frame: 106 , param: 0.8916666666666666
# animating frame: 106 , param: 160.5
# 80 1/4 0.325
#  45% 107/240 [01:11<01:25,  1.56it/s]animating frame: 107 , param: 0.9
# animating frame: 107 , param: 162.0
# 80 1/4 0.3375
#  45% 108/240 [01:12<01:24,  1.57it/s]animating frame: 108 , param: 0.9083333333333333
# animating frame: 108 , param: 163.5
# 80 1/4 0.35
#  45% 109/240 [01:12<01:23,  1.57it/s]animating frame: 109 , param: 0.9166666666666666
# animating frame: 109 , param: 165.0
# 80 1/4 0.3625
#  46% 110/240 [01:13<01:23,  1.57it/s]animating frame: 110 , param: 0.9249999999999999
# animating frame: 110 , param: 166.5
# 80 1/4 0.375
#  46% 111/240 [01:13<01:22,  1.56it/s]animating frame: 111 , param: 0.9333333333333333
# animating frame: 111 , param: 168.0
# 80 1/4 0.3875
#  47% 112/240 [01:14<01:22,  1.55it/s]animating frame: 112 , param: 0.9416666666666667
# animating frame: 112 , param: 169.5
# 80 1/4 0.4
#  47% 113/240 [01:15<01:21,  1.55it/s]animating frame: 113 , param: 0.95
# animating frame: 113 , param: 171.0
# 80 1/4 0.4125
#  48% 114/240 [01:15<01:21,  1.55it/s]animating frame: 114 , param: 0.9583333333333334
# animating frame: 114 , param: 172.5
# 80 1/4 0.425
#  48% 115/240 [01:16<01:20,  1.55it/s]animating frame: 115 , param: 0.9666666666666667
# animating frame: 115 , param: 174.0
# 80 1/4 0.4375
#  48% 116/240 [01:17<01:19,  1.55it/s]animating frame: 116 , param: 0.975
# animating frame: 116 , param: 175.5
# 80 1/4 0.45
#  49% 117/240 [01:17<01:19,  1.56it/s]animating frame: 117 , param: 0.9833333333333333
# animating frame: 117 , param: 177.0
# 80 1/4 0.4625
#  49% 118/240 [01:18<01:17,  1.57it/s]animating frame: 118 , param: 0.9916666666666667
# animating frame: 118 , param: 178.5
# 80 1/4 0.475
#  50% 119/240 [01:19<01:16,  1.57it/s]animating frame: 119 , param: 1.0
# animating frame: 119 , param: 180.0
# 80 1/4 0.4875
#  50% 120/240 [01:19<01:15,  1.59it/s]animating frame: 120 , param: 1.0083333333333333
# animating frame: 120 , param: 181.5
# 80 1/4 0.5
#  50% 121/240 [01:20<01:14,  1.59it/s]animating frame: 121 , param: 1.0166666666666666
# animating frame: 121 , param: 183.0
# 80 1/4 0.5125
#  51% 122/240 [01:20<01:14,  1.58it/s]animating frame: 122 , param: 1.025
# animating frame: 122 , param: 184.5
# 80 1/4 0.525
#  51% 123/240 [01:21<01:15,  1.55it/s]animating frame: 123 , param: 1.0333333333333332
# animating frame: 123 , param: 186.0
# 80 1/4 0.5375
#  52% 124/240 [01:22<01:15,  1.53it/s]animating frame: 124 , param: 1.0416666666666667
# animating frame: 124 , param: 187.5
# 80 1/4 0.55
#  52% 125/240 [01:22<01:16,  1.51it/s]animating frame: 125 , param: 1.05
# animating frame: 125 , param: 189.0
# 80 1/4 0.5625
#  52% 126/240 [01:23<01:15,  1.50it/s]animating frame: 126 , param: 1.0583333333333333
# animating frame: 126 , param: 190.5
# 80 1/4 0.575
#  53% 127/240 [01:24<01:15,  1.50it/s]animating frame: 127 , param: 1.0666666666666667
# animating frame: 127 , param: 192.0
# 80 1/4 0.5875
#  53% 128/240 [01:25<01:14,  1.49it/s]animating frame: 128 , param: 1.075
# animating frame: 128 , param: 193.5
# 80 1/4 0.6
#  54% 129/240 [01:25<01:14,  1.49it/s]animating frame: 129 , param: 1.0833333333333333
# animating frame: 129 , param: 195.0
# 80 1/4 0.6125
#  54% 130/240 [01:26<01:14,  1.49it/s]animating frame: 130 , param: 1.0916666666666666
# animating frame: 130 , param: 196.5
# 80 1/4 0.625
#  55% 131/240 [01:27<01:13,  1.48it/s]animating frame: 131 , param: 1.1
# animating frame: 131 , param: 198.0
# 80 1/4 0.6375
#  55% 132/240 [01:27<01:12,  1.48it/s]animating frame: 132 , param: 1.1083333333333334
# animating frame: 132 , param: 199.5
# 80 1/4 0.65
#  55% 133/240 [01:28<01:12,  1.47it/s]animating frame: 133 , param: 1.1166666666666667
# animating frame: 133 , param: 201.0
# 80 1/4 0.6625
#  56% 134/240 [01:29<01:12,  1.47it/s]animating frame: 134 , param: 1.125
# animating frame: 134 , param: 202.5
# 80 1/4 0.675
#  56% 135/240 [01:29<01:11,  1.47it/s]animating frame: 135 , param: 1.1333333333333333
# animating frame: 135 , param: 204.0
# 80 1/4 0.6875
#  57% 136/240 [01:30<01:10,  1.48it/s]animating frame: 136 , param: 1.1416666666666666
# animating frame: 136 , param: 205.5
# 80 1/4 0.7
#  57% 137/240 [01:31<01:09,  1.48it/s]animating frame: 137 , param: 1.15
# animating frame: 137 , param: 207.0
# 80 1/4 0.7125
#  57% 138/240 [01:31<01:08,  1.48it/s]animating frame: 138 , param: 1.1583333333333332
# animating frame: 138 , param: 208.5
# 80 1/4 0.725
#  58% 139/240 [01:32<01:08,  1.48it/s]animating frame: 139 , param: 1.1666666666666667
# animating frame: 139 , param: 210.0
# 80 1/4 0.7375
#  58% 140/240 [01:33<01:07,  1.49it/s]animating frame: 140 , param: 1.175
# animating frame: 140 , param: 211.5
# 80 1/4 0.75
#  59% 141/240 [01:33<01:06,  1.49it/s]animating frame: 141 , param: 1.1833333333333333
# animating frame: 141 , param: 213.0
# 80 1/4 0.7625
#  59% 142/240 [01:34<01:05,  1.49it/s]animating frame: 142 , param: 1.1916666666666667
# animating frame: 142 , param: 214.5
# 80 1/4 0.775
#  60% 143/240 [01:35<01:05,  1.49it/s]animating frame: 143 , param: 1.2
# animating frame: 143 , param: 216.0
# 80 1/4 0.7875
#  60% 144/240 [01:35<01:04,  1.49it/s]animating frame: 144 , param: 1.2083333333333333
# animating frame: 144 , param: 217.5
# 80 1/4 0.8
#  60% 145/240 [01:36<01:03,  1.49it/s]animating frame: 145 , param: 1.2166666666666666
# animating frame: 145 , param: 219.0
# 80 1/4 0.8125
#  61% 146/240 [01:37<01:02,  1.50it/s]animating frame: 146 , param: 1.225
# animating frame: 146 , param: 220.5
# 80 1/4 0.825
#  61% 147/240 [01:37<01:01,  1.52it/s]animating frame: 147 , param: 1.2333333333333334
# animating frame: 147 , param: 222.0
# 80 1/4 0.8375
#  62% 148/240 [01:38<00:58,  1.56it/s]animating frame: 148 , param: 1.2416666666666667
# animating frame: 148 , param: 223.5
# 80 1/4 0.85
#  62% 149/240 [01:38<00:56,  1.61it/s]animating frame: 149 , param: 1.25
# animating frame: 149 , param: 225.0
# 80 1/4 0.8625
#  62% 150/240 [01:39<00:54,  1.66it/s]animating frame: 150 , param: 1.2583333333333333
# animating frame: 150 , param: 226.5
# 80 1/4 0.875
#  63% 151/240 [01:40<00:51,  1.71it/s]animating frame: 151 , param: 1.2666666666666666
# animating frame: 151 , param: 228.0
# 80 1/4 0.8875
#  63% 152/240 [01:40<00:49,  1.77it/s]animating frame: 152 , param: 1.275
# animating frame: 152 , param: 229.5
# 80 1/4 0.9
#  64% 153/240 [01:41<00:47,  1.82it/s]animating frame: 153 , param: 1.2833333333333332
# animating frame: 153 , param: 231.0
# 80 1/4 0.9125
#  64% 154/240 [01:41<00:45,  1.89it/s]animating frame: 154 , param: 1.2916666666666667
# animating frame: 154 , param: 232.5
# 80 1/4 0.925
#  65% 155/240 [01:42<00:43,  1.95it/s]animating frame: 155 , param: 1.3
# animating frame: 155 , param: 234.0
# 80 1/4 0.9375
#  65% 156/240 [01:42<00:41,  2.02it/s]animating frame: 156 , param: 1.3083333333333333
# animating frame: 156 , param: 235.5
# 80 1/4 0.95
#  65% 157/240 [01:42<00:39,  2.08it/s]animating frame: 157 , param: 1.3166666666666667
# animating frame: 157 , param: 237.0
# 80 1/4 0.9625
#  66% 158/240 [01:43<00:38,  2.16it/s]animating frame: 158 , param: 1.325
# animating frame: 158 , param: 238.5
# 80 1/4 0.975
#  66% 159/240 [01:43<00:36,  2.21it/s]animating frame: 159 , param: 1.3333333333333333
# animating frame: 159 , param: 240.0
# 80 1/4 0.9875
#  67% 160/240 [01:44<00:35,  2.26it/s]animating frame: 160 , param: 1.3416666666666666
# animating frame: 160 , param: 241.5
# 80 2/4 0.0
#  67% 161/240 [01:44<00:34,  2.31it/s]animating frame: 161 , param: 1.35
# animating frame: 161 , param: 243.0
# 80 2/4 0.0125
#  68% 162/240 [01:45<00:33,  2.34it/s]animating frame: 162 , param: 1.3583333333333334
# animating frame: 162 , param: 244.5
# 80 2/4 0.025
#  68% 163/240 [01:45<00:32,  2.37it/s]animating frame: 163 , param: 1.3666666666666667
# animating frame: 163 , param: 246.0
# 80 2/4 0.0375
#  68% 164/240 [01:45<00:31,  2.39it/s]animating frame: 164 , param: 1.375
# animating frame: 164 , param: 247.5
# 80 2/4 0.05
#  69% 165/240 [01:46<00:31,  2.40it/s]animating frame: 165 , param: 1.3833333333333333
# animating frame: 165 , param: 249.0
# 80 2/4 0.0625
#  69% 166/240 [01:46<00:30,  2.41it/s]animating frame: 166 , param: 1.3916666666666666
# animating frame: 166 , param: 250.5
# 80 2/4 0.075
#  70% 167/240 [01:47<00:30,  2.38it/s]animating frame: 167 , param: 1.4
# animating frame: 167 , param: 252.0
# 80 2/4 0.0875
#  70% 168/240 [01:47<00:30,  2.40it/s]animating frame: 168 , param: 1.4083333333333332
# animating frame: 168 , param: 253.5
# 80 2/4 0.1
#  70% 169/240 [01:47<00:29,  2.39it/s]animating frame: 169 , param: 1.4166666666666667
# animating frame: 169 , param: 255.0
# 80 2/4 0.1125
#  71% 170/240 [01:48<00:29,  2.41it/s]animating frame: 170 , param: 1.425
# animating frame: 170 , param: 256.5
# 80 2/4 0.125
#  71% 171/240 [01:48<00:28,  2.42it/s]animating frame: 171 , param: 1.4333333333333333
# animating frame: 171 , param: 258.0
# 80 2/4 0.1375
#  72% 172/240 [01:49<00:27,  2.43it/s]animating frame: 172 , param: 1.4416666666666667
# animating frame: 172 , param: 259.5
# 80 2/4 0.15
#  72% 173/240 [01:49<00:27,  2.40it/s]animating frame: 173 , param: 1.45
# animating frame: 173 , param: 261.0
# 80 2/4 0.1625
#  72% 174/240 [01:50<00:27,  2.38it/s]animating frame: 174 , param: 1.4583333333333333
# animating frame: 174 , param: 262.5
# 80 2/4 0.175
#  73% 175/240 [01:50<00:27,  2.36it/s]animating frame: 175 , param: 1.4666666666666666
# animating frame: 175 , param: 264.0
# 80 2/4 0.1875
#  73% 176/240 [01:50<00:27,  2.32it/s]animating frame: 176 , param: 1.475
# animating frame: 176 , param: 265.5
# 80 2/4 0.2
#  74% 177/240 [01:51<00:27,  2.30it/s]animating frame: 177 , param: 1.4833333333333334
# animating frame: 177 , param: 267.0
# 80 2/4 0.2125
#  74% 178/240 [01:51<00:27,  2.27it/s]animating frame: 178 , param: 1.4916666666666667
# animating frame: 178 , param: 268.5
# 80 2/4 0.225
#  75% 179/240 [01:52<00:27,  2.23it/s]animating frame: 179 , param: 1.5
# animating frame: 179 , param: 270.0
# 80 2/4 0.2375
#  75% 180/240 [01:52<00:27,  2.19it/s]animating frame: 180 , param: 1.5083333333333333
# animating frame: 180 , param: 271.5
# 80 2/4 0.25
#  75% 181/240 [01:53<00:27,  2.16it/s]animating frame: 181 , param: 1.5166666666666666
# animating frame: 181 , param: 273.0
# 80 2/4 0.2625
#  76% 182/240 [01:53<00:27,  2.13it/s]animating frame: 182 , param: 1.525
# animating frame: 182 , param: 274.5
# 80 2/4 0.275
#  76% 183/240 [01:54<00:27,  2.10it/s]animating frame: 183 , param: 1.5333333333333332
# animating frame: 183 , param: 276.0
# 80 2/4 0.2875
#  77% 184/240 [01:54<00:26,  2.08it/s]animating frame: 184 , param: 1.5416666666666667
# animating frame: 184 , param: 277.5
# 80 2/4 0.3
#  77% 185/240 [01:55<00:26,  2.05it/s]animating frame: 185 , param: 1.55
# animating frame: 185 , param: 279.0
# 80 2/4 0.3125
#  78% 186/240 [01:55<00:26,  2.03it/s]animating frame: 186 , param: 1.5583333333333333
# animating frame: 186 , param: 280.5
# 80 2/4 0.325
#  78% 187/240 [01:56<00:26,  2.02it/s]animating frame: 187 , param: 1.5666666666666667
# animating frame: 187 , param: 282.0
# 80 2/4 0.3375
#  78% 188/240 [01:56<00:25,  2.01it/s]animating frame: 188 , param: 1.575
# animating frame: 188 , param: 283.5
# 80 2/4 0.35
#  79% 189/240 [01:57<00:25,  1.99it/s]animating frame: 189 , param: 1.5833333333333333
# animating frame: 189 , param: 285.0
# 80 2/4 0.3625
#  79% 190/240 [01:57<00:25,  2.00it/s]animating frame: 190 , param: 1.5916666666666666
# animating frame: 190 , param: 286.5
# 80 2/4 0.375
#  80% 191/240 [01:58<00:24,  2.01it/s]animating frame: 191 , param: 1.6
# animating frame: 191 , param: 288.0
# 80 2/4 0.3875
#  80% 192/240 [01:58<00:23,  2.01it/s]animating frame: 192 , param: 1.6083333333333334
# animating frame: 192 , param: 289.5
# 80 2/4 0.4
#  80% 193/240 [01:59<00:23,  2.02it/s]animating frame: 193 , param: 1.6166666666666667
# animating frame: 193 , param: 291.0
# 80 2/4 0.4125
#  81% 194/240 [01:59<00:22,  2.02it/s]animating frame: 194 , param: 1.625
# animating frame: 194 , param: 292.5
# 80 2/4 0.425
#  81% 195/240 [02:00<00:22,  2.04it/s]animating frame: 195 , param: 1.6333333333333333
# animating frame: 195 , param: 294.0
# 80 2/4 0.4375
#  82% 196/240 [02:00<00:21,  2.06it/s]animating frame: 196 , param: 1.6416666666666666
# animating frame: 196 , param: 295.5
# 80 2/4 0.45
#  82% 197/240 [02:01<00:20,  2.07it/s]animating frame: 197 , param: 1.65
# animating frame: 197 , param: 297.0
# 80 2/4 0.4625
#  82% 198/240 [02:01<00:20,  2.05it/s]animating frame: 198 , param: 1.6583333333333332
# animating frame: 198 , param: 298.5
# 80 2/4 0.475
#  83% 199/240 [02:02<00:20,  2.05it/s]animating frame: 199 , param: 1.6666666666666667
# animating frame: 199 , param: 300.0
# 80 2/4 0.4875
#  83% 200/240 [02:02<00:19,  2.07it/s]animating frame: 200 , param: 1.675
# animating frame: 200 , param: 301.5
# 80 2/4 0.5
#  84% 201/240 [02:03<00:18,  2.08it/s]animating frame: 201 , param: 1.6833333333333333
# animating frame: 201 , param: 303.0
# 80 2/4 0.5125
#  84% 202/240 [02:03<00:18,  2.09it/s]animating frame: 202 , param: 1.6916666666666667
# animating frame: 202 , param: 304.5
# 80 2/4 0.525
#  85% 203/240 [02:03<00:17,  2.10it/s]animating frame: 203 , param: 1.7
# animating frame: 203 , param: 306.0
# 80 2/4 0.5375
#  85% 204/240 [02:04<00:17,  2.10it/s]animating frame: 204 , param: 1.7083333333333333
# animating frame: 204 , param: 307.5
# 80 2/4 0.55
#  85% 205/240 [02:04<00:16,  2.11it/s]animating frame: 205 , param: 1.7166666666666666
# animating frame: 205 , param: 309.0
# 80 2/4 0.5625
#  86% 206/240 [02:05<00:16,  2.11it/s]animating frame: 206 , param: 1.7249999999999999
# animating frame: 206 , param: 310.5
# 80 2/4 0.575
#  86% 207/240 [02:05<00:15,  2.11it/s]animating frame: 207 , param: 1.7333333333333334
# animating frame: 207 , param: 312.0
# 80 2/4 0.5875
#  87% 208/240 [02:06<00:15,  2.11it/s]animating frame: 208 , param: 1.7416666666666667
# animating frame: 208 , param: 313.5
# 80 2/4 0.6
#  87% 209/240 [02:06<00:14,  2.12it/s]animating frame: 209 , param: 1.75
# animating frame: 209 , param: 315.0
# 80 2/4 0.6125
#  88% 210/240 [02:07<00:14,  2.12it/s]animating frame: 210 , param: 1.7583333333333333
# animating frame: 210 , param: 316.5
# 80 2/4 0.625
#  88% 211/240 [02:07<00:13,  2.12it/s]animating frame: 211 , param: 1.7666666666666666
# animating frame: 211 , param: 318.0
# 80 2/4 0.6375
#  88% 212/240 [02:08<00:13,  2.13it/s]animating frame: 212 , param: 1.775
# animating frame: 212 , param: 319.5
# 80 2/4 0.65
#  89% 213/240 [02:08<00:12,  2.14it/s]animating frame: 213 , param: 1.7833333333333332
# animating frame: 213 , param: 321.0
# 80 2/4 0.6625
#  89% 214/240 [02:09<00:12,  2.14it/s]animating frame: 214 , param: 1.7916666666666667
# animating frame: 214 , param: 322.5
# 80 2/4 0.675
#  90% 215/240 [02:09<00:11,  2.15it/s]animating frame: 215 , param: 1.8
# animating frame: 215 , param: 324.0
# 80 2/4 0.6875
#  90% 216/240 [02:10<00:11,  2.14it/s]animating frame: 216 , param: 1.8083333333333333
# animating frame: 216 , param: 325.5
# 80 2/4 0.7
#  90% 217/240 [02:10<00:10,  2.14it/s]animating frame: 217 , param: 1.8166666666666667
# animating frame: 217 , param: 327.0
# 80 2/4 0.7125
#  91% 218/240 [02:11<00:10,  2.15it/s]animating frame: 218 , param: 1.825
# animating frame: 218 , param: 328.5
# 80 2/4 0.725
#  91% 219/240 [02:11<00:09,  2.15it/s]animating frame: 219 , param: 1.8333333333333333
# animating frame: 219 , param: 330.0
# 80 2/4 0.7375
#  92% 220/240 [02:11<00:09,  2.16it/s]animating frame: 220 , param: 1.8416666666666666
# animating frame: 220 , param: 331.5
# 80 2/4 0.75
#  92% 221/240 [02:12<00:08,  2.14it/s]animating frame: 221 , param: 1.8499999999999999
# animating frame: 221 , param: 333.0
# 80 2/4 0.7625
#  92% 222/240 [02:12<00:08,  2.14it/s]animating frame: 222 , param: 1.8583333333333334
# animating frame: 222 , param: 334.5
# 80 2/4 0.775
#  93% 223/240 [02:13<00:07,  2.16it/s]animating frame: 223 , param: 1.8666666666666667
# animating frame: 223 , param: 336.0
# 80 2/4 0.7875
#  93% 224/240 [02:13<00:07,  2.17it/s]animating frame: 224 , param: 1.875
# animating frame: 224 , param: 337.5
# 80 2/4 0.8
#  94% 225/240 [02:14<00:06,  2.18it/s]animating frame: 225 , param: 1.8833333333333333
# animating frame: 225 , param: 339.0
# 80 2/4 0.8125
#  94% 226/240 [02:14<00:06,  2.14it/s]animating frame: 226 , param: 1.8916666666666666
# animating frame: 226 , param: 340.5
# 80 2/4 0.825
#  95% 227/240 [02:15<00:06,  2.16it/s]animating frame: 227 , param: 1.9
# animating frame: 227 , param: 342.0
# 80 2/4 0.8375
#  95% 228/240 [02:15<00:05,  2.16it/s]animating frame: 228 , param: 1.9083333333333332
# animating frame: 228 , param: 343.5
# 80 2/4 0.85
#  95% 229/240 [02:16<00:05,  2.18it/s]animating frame: 229 , param: 1.9166666666666667
# animating frame: 229 , param: 345.0
# 80 2/4 0.8625
#  96% 230/240 [02:16<00:04,  2.18it/s]animating frame: 230 , param: 1.925
# animating frame: 230 , param: 346.5
# 80 2/4 0.875
#  96% 231/240 [02:17<00:04,  2.18it/s]animating frame: 231 , param: 1.9333333333333333
# animating frame: 231 , param: 348.0
# 80 2/4 0.8875
#  97% 232/240 [02:17<00:03,  2.19it/s]animating frame: 232 , param: 1.9416666666666667
# animating frame: 232 , param: 349.5
# 80 2/4 0.9
#  97% 233/240 [02:17<00:03,  2.22it/s]animating frame: 233 , param: 1.95
# animating frame: 233 , param: 351.0
# 80 2/4 0.9125
#  98% 234/240 [02:18<00:02,  2.23it/s]animating frame: 234 , param: 1.9583333333333333
# animating frame: 234 , param: 352.5
# 80 2/4 0.925
#  98% 235/240 [02:18<00:02,  2.26it/s]animating frame: 235 , param: 1.9666666666666666
# animating frame: 235 , param: 354.0
# 80 2/4 0.9375
#  98% 236/240 [02:19<00:01,  2.28it/s]animating frame: 236 , param: 1.9749999999999999
# animating frame: 236 , param: 355.5
# 80 2/4 0.95
#  99% 237/240 [02:19<00:01,  2.30it/s]animating frame: 237 , param: 1.9833333333333334
# animating frame: 237 , param: 357.0
# 80 2/4 0.9625
#  99% 238/240 [02:20<00:00,  2.32it/s]animating frame: 238 , param: 1.9916666666666667
# animating frame: 238 , param: 358.5
# 80 2/4 0.975
# 100% 239/240 [02:20<00:00,  2.31it/s]animating frame: 239 , param: 2.0
# animating frame: 239 , param: 360.0
# 80 2/4 0.9875
# 100% 240/240 [02:20<00:00,  1.70it/s]
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ladiesblack-multi-test/frame%06d.png':
#   Duration: 00:00:09.60, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55fc5e073e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55fc5e073e00] profile High, level 3.2
# [libx264 @ 0x55fc5e073e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'ladiesblack-multi-test/bend.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  240 fps= 14 q=-1.0 Lsize=    4839kB time=00:00:09.87 bitrate=4014.3kbits/s speed=0.585x
# video:4836kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.068258%
# [libx264 @ 0x55fc5e073e00] frame I:1     Avg QP:16.30  size: 71732
# [libx264 @ 0x55fc5e073e00] frame P:109   Avg QP:22.46  size: 32563
# [libx264 @ 0x55fc5e073e00] frame B:130   Avg QP:26.76  size: 10231
# [libx264 @ 0x55fc5e073e00] consecutive B-frames: 25.4%  6.7%  1.2% 66.7%
# [libx264 @ 0x55fc5e073e00] mb I  I16..4:  3.5% 96.5%  0.0%
# [libx264 @ 0x55fc5e073e00] mb P  I16..4:  0.1%  3.2%  2.4%  P16..4: 28.2%  9.6%  8.3%  0.0%  0.0%    skip:48.1%
# [libx264 @ 0x55fc5e073e00] mb B  I16..4:  0.0%  0.2%  0.3%  B16..8: 18.0%  1.8%  1.4%  direct:10.8%  skip:67.4%  L0:39.0% L1:53.4% BI: 7.6%
# [libx264 @ 0x55fc5e073e00] 8x8 transform intra:59.4% inter:60.2%
# [libx264 @ 0x55fc5e073e00] coded y,uvDC,uvAC intra: 89.6% 58.8% 31.7% inter: 19.1% 10.0% 0.5%
# [libx264 @ 0x55fc5e073e00] i16 v,h,dc,p: 31% 10% 40% 19%
# [libx264 @ 0x55fc5e073e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21%  5% 26%  9%  5%  9%  5% 15%  6%
# [libx264 @ 0x55fc5e073e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22%  6% 19% 11%  6%  9%  5% 14%  7%
# [libx264 @ 0x55fc5e073e00] i8c dc,h,v,p: 63% 10% 22%  5%
# [libx264 @ 0x55fc5e073e00] Weighted P-Frames: Y:14.7% UV:11.9%
# [libx264 @ 0x55fc5e073e00] ref P L0: 66.2% 16.8% 12.8%  3.4%  0.8%
# [libx264 @ 0x55fc5e073e00] ref B L0: 89.7%  8.2%  2.1%
# [libx264 @ 0x55fc5e073e00] ref B L1: 94.3%  5.7%
# [libx264 @ 0x55fc5e073e00] kb/s:3960.89

# %% [markdown]
# ### Interpolating Noise
#
# You may find that the detail textures on your bend animations seem too similar. You can add `--noise_interpolation`

# %%
# !python animate.py \
--ckpt /content/ladiesblack.pt \
--load_latent /content/network-bending/sample/latents.yaml \
--latent_id 414 \
--num_frames 240 \
--transform "scale,rotate" \
--init_val 0.0,0.0 \
--end_val 0.8,720.0 \
--layer_id 1,1 \
--truncation=0.5 \
--interpolate_ids=1,4,19,24,11,1 \
--dir="ladiesblack-multi-test-noise2" \
--noise_interpolation
# Out:
# [0.0, 0.0]
# 2
#   0% 0/240 [00:00<?, ?it/s]animating frame: 0 , param: 0.0033333333333333335
# animating frame: 0 , param: 3.0
# 48 0/6 0.0
#   0% 1/240 [00:00<02:29,  1.60it/s]animating frame: 1 , param: 0.006666666666666667
# animating frame: 1 , param: 6.0
# 48 0/6 0.020833333333333332
#   1% 2/240 [00:01<02:22,  1.67it/s]animating frame: 2 , param: 0.01
# animating frame: 2 , param: 9.0
# 48 0/6 0.041666666666666664
#   1% 3/240 [00:01<02:19,  1.70it/s]animating frame: 3 , param: 0.013333333333333334
# animating frame: 3 , param: 12.0
# 48 0/6 0.0625
#   2% 4/240 [00:02<02:17,  1.71it/s]animating frame: 4 , param: 0.016666666666666666
# animating frame: 4 , param: 15.0
# 48 0/6 0.08333333333333333
#   2% 5/240 [00:02<02:18,  1.70it/s]animating frame: 5 , param: 0.02
# animating frame: 5 , param: 18.0
# 48 0/6 0.10416666666666667
#   2% 6/240 [00:03<02:20,  1.66it/s]animating frame: 6 , param: 0.023333333333333334
# animating frame: 6 , param: 21.0
# 48 0/6 0.125
#   3% 7/240 [00:04<02:22,  1.63it/s]animating frame: 7 , param: 0.02666666666666667
# animating frame: 7 , param: 24.0
# 48 0/6 0.14583333333333334
#   3% 8/240 [00:04<02:25,  1.60it/s]animating frame: 8 , param: 0.030000000000000002
# animating frame: 8 , param: 27.0
# 48 0/6 0.16666666666666666
#   4% 9/240 [00:05<02:27,  1.57it/s]animating frame: 9 , param: 0.03333333333333333
# animating frame: 9 , param: 30.0
# 48 0/6 0.1875
#   4% 10/240 [00:06<02:28,  1.55it/s]animating frame: 10 , param: 0.03666666666666667
# animating frame: 10 , param: 33.0
# 48 0/6 0.20833333333333334
#   5% 11/240 [00:06<02:30,  1.53it/s]animating frame: 11 , param: 0.04
# animating frame: 11 , param: 36.0
# 48 0/6 0.22916666666666666
#   5% 12/240 [00:07<02:30,  1.51it/s]animating frame: 12 , param: 0.043333333333333335
# animating frame: 12 , param: 39.0
# 48 0/6 0.25
#   5% 13/240 [00:08<02:31,  1.49it/s]animating frame: 13 , param: 0.04666666666666667
# animating frame: 13 , param: 42.0
# 48 0/6 0.2708333333333333
#   6% 14/240 [00:08<02:33,  1.48it/s]animating frame: 14 , param: 0.05
# animating frame: 14 , param: 45.0
# 48 0/6 0.2916666666666667
#   6% 15/240 [00:09<02:33,  1.47it/s]animating frame: 15 , param: 0.05333333333333334
# animating frame: 15 , param: 48.0
# 48 0/6 0.3125
#   7% 16/240 [00:10<02:34,  1.45it/s]animating frame: 16 , param: 0.05666666666666667
# animating frame: 16 , param: 51.0
# 48 0/6 0.3333333333333333
#   7% 17/240 [00:10<02:34,  1.44it/s]animating frame: 17 , param: 0.060000000000000005
# animating frame: 17 , param: 54.0
# 48 0/6 0.3541666666666667
#   8% 18/240 [00:11<02:34,  1.43it/s]animating frame: 18 , param: 0.06333333333333334
# animating frame: 18 , param: 57.0
# 48 0/6 0.375
#   8% 19/240 [00:12<02:34,  1.43it/s]animating frame: 19 , param: 0.06666666666666667
# animating frame: 19 , param: 60.0
# 48 0/6 0.3958333333333333
#   8% 20/240 [00:13<02:33,  1.43it/s]animating frame: 20 , param: 0.07
# animating frame: 20 , param: 63.0
# 48 0/6 0.4166666666666667
#   9% 21/240 [00:13<02:33,  1.43it/s]animating frame: 21 , param: 0.07333333333333333
# animating frame: 21 , param: 66.0
# 48 0/6 0.4375
#   9% 22/240 [00:14<02:33,  1.42it/s]animating frame: 22 , param: 0.07666666666666667
# animating frame: 22 , param: 69.0
# 48 0/6 0.4583333333333333
#  10% 23/240 [00:15<02:32,  1.42it/s]animating frame: 23 , param: 0.08
# animating frame: 23 , param: 72.0
# 48 0/6 0.4791666666666667
#  10% 24/240 [00:15<02:31,  1.43it/s]animating frame: 24 , param: 0.08333333333333334
# animating frame: 24 , param: 75.0
# 48 0/6 0.5
#  10% 25/240 [00:16<02:30,  1.43it/s]animating frame: 25 , param: 0.08666666666666667
# animating frame: 25 , param: 78.0
# 48 0/6 0.5208333333333334
#  11% 26/240 [00:17<02:29,  1.43it/s]animating frame: 26 , param: 0.09000000000000001
# animating frame: 26 , param: 81.0
# 48 0/6 0.5416666666666666
#  11% 27/240 [00:18<02:29,  1.43it/s]animating frame: 27 , param: 0.09333333333333334
# animating frame: 27 , param: 84.0
# 48 0/6 0.5625
#  12% 28/240 [00:18<02:28,  1.43it/s]animating frame: 28 , param: 0.09666666666666668
# animating frame: 28 , param: 87.0
# 48 0/6 0.5833333333333334
#  12% 29/240 [00:19<02:27,  1.43it/s]animating frame: 29 , param: 0.1
# animating frame: 29 , param: 90.0
# 48 0/6 0.6041666666666666
#  12% 30/240 [00:20<02:27,  1.43it/s]animating frame: 30 , param: 0.10333333333333335
# animating frame: 30 , param: 93.0
# 48 0/6 0.625
#  13% 31/240 [00:20<02:27,  1.41it/s]animating frame: 31 , param: 0.10666666666666667
# animating frame: 31 , param: 96.0
# 48 0/6 0.6458333333333334
#  13% 32/240 [00:21<02:26,  1.42it/s]animating frame: 32 , param: 0.11
# animating frame: 32 , param: 99.0
# 48 0/6 0.6666666666666666
#  14% 33/240 [00:22<02:24,  1.43it/s]animating frame: 33 , param: 0.11333333333333334
# animating frame: 33 , param: 102.0
# 48 0/6 0.6875
#  14% 34/240 [00:22<02:22,  1.45it/s]animating frame: 34 , param: 0.11666666666666667
# animating frame: 34 , param: 105.0
# 48 0/6 0.7083333333333334
#  15% 35/240 [00:23<02:19,  1.46it/s]animating frame: 35 , param: 0.12000000000000001
# animating frame: 35 , param: 108.0
# 48 0/6 0.7291666666666666
#  15% 36/240 [00:24<02:17,  1.48it/s]animating frame: 36 , param: 0.12333333333333334
# animating frame: 36 , param: 111.0
# 48 0/6 0.75
#  15% 37/240 [00:24<02:16,  1.49it/s]animating frame: 37 , param: 0.12666666666666668
# animating frame: 37 , param: 114.0
# 48 0/6 0.7708333333333334
#  16% 38/240 [00:25<02:14,  1.51it/s]animating frame: 38 , param: 0.13
# animating frame: 38 , param: 117.0
# 48 0/6 0.7916666666666666
#  16% 39/240 [00:26<02:12,  1.52it/s]animating frame: 39 , param: 0.13333333333333333
# animating frame: 39 , param: 120.0
# 48 0/6 0.8125
#  17% 40/240 [00:26<02:10,  1.53it/s]animating frame: 40 , param: 0.1366666666666667
# animating frame: 40 , param: 123.0
# 48 0/6 0.8333333333333334
#  17% 41/240 [00:27<02:08,  1.54it/s]animating frame: 41 , param: 0.14
# animating frame: 41 , param: 126.0
# 48 0/6 0.8541666666666666
#  18% 42/240 [00:28<02:07,  1.56it/s]animating frame: 42 , param: 0.14333333333333334
# animating frame: 42 , param: 129.0
# 48 0/6 0.875
#  18% 43/240 [00:28<02:05,  1.57it/s]animating frame: 43 , param: 0.14666666666666667
# animating frame: 43 , param: 132.0
# 48 0/6 0.8958333333333334
#  18% 44/240 [00:29<02:03,  1.58it/s]animating frame: 44 , param: 0.15000000000000002
# animating frame: 44 , param: 135.0
# 48 0/6 0.9166666666666666
#  19% 45/240 [00:29<02:01,  1.60it/s]animating frame: 45 , param: 0.15333333333333335
# animating frame: 45 , param: 138.0
# 48 0/6 0.9375
#  19% 46/240 [00:30<02:00,  1.61it/s]animating frame: 46 , param: 0.15666666666666668
# animating frame: 46 , param: 141.0
# 48 0/6 0.9583333333333334
#  20% 47/240 [00:31<01:59,  1.62it/s]animating frame: 47 , param: 0.16
# animating frame: 47 , param: 144.0
# 48 0/6 0.9791666666666666
#  20% 48/240 [00:31<01:56,  1.64it/s]animating frame: 48 , param: 0.16333333333333333
# animating frame: 48 , param: 147.0
# 48 1/6 0.0
#  20% 49/240 [00:32<01:54,  1.66it/s]animating frame: 49 , param: 0.16666666666666669
# animating frame: 49 , param: 150.0
# 48 1/6 0.020833333333333332
#  21% 50/240 [00:32<01:53,  1.68it/s]animating frame: 50 , param: 0.17
# animating frame: 50 , param: 153.0
# 48 1/6 0.041666666666666664
#  21% 51/240 [00:33<01:52,  1.68it/s]animating frame: 51 , param: 0.17333333333333334
# animating frame: 51 , param: 156.0
# 48 1/6 0.0625
#  22% 52/240 [00:34<01:51,  1.69it/s]animating frame: 52 , param: 0.17666666666666667
# animating frame: 52 , param: 159.0
# 48 1/6 0.08333333333333333
#  22% 53/240 [00:34<01:50,  1.69it/s]animating frame: 53 , param: 0.18000000000000002
# animating frame: 53 , param: 162.0
# 48 1/6 0.10416666666666667
#  22% 54/240 [00:35<01:49,  1.70it/s]animating frame: 54 , param: 0.18333333333333335
# animating frame: 54 , param: 165.0
# 48 1/6 0.125
#  23% 55/240 [00:35<01:48,  1.71it/s]animating frame: 55 , param: 0.18666666666666668
# animating frame: 55 , param: 168.0
# 48 1/6 0.14583333333333334
#  23% 56/240 [00:36<01:47,  1.72it/s]animating frame: 56 , param: 0.19
# animating frame: 56 , param: 171.0
# 48 1/6 0.16666666666666666
#  24% 57/240 [00:36<01:45,  1.73it/s]animating frame: 57 , param: 0.19333333333333336
# animating frame: 57 , param: 174.0
# 48 1/6 0.1875
#  24% 58/240 [00:37<01:45,  1.73it/s]animating frame: 58 , param: 0.19666666666666668
# animating frame: 58 , param: 177.0
# 48 1/6 0.20833333333333334
#  25% 59/240 [00:38<01:43,  1.74it/s]animating frame: 59 , param: 0.2
# animating frame: 59 , param: 180.0
# 48 1/6 0.22916666666666666
#  25% 60/240 [00:38<01:42,  1.75it/s]animating frame: 60 , param: 0.20333333333333334
# animating frame: 60 , param: 183.0
# 48 1/6 0.25
#  25% 61/240 [00:39<01:41,  1.76it/s]animating frame: 61 , param: 0.2066666666666667
# animating frame: 61 , param: 186.0
# 48 1/6 0.2708333333333333
#  26% 62/240 [00:39<01:41,  1.76it/s]animating frame: 62 , param: 0.21000000000000002
# animating frame: 62 , param: 189.0
# 48 1/6 0.2916666666666667
#  26% 63/240 [00:40<01:40,  1.77it/s]animating frame: 63 , param: 0.21333333333333335
# animating frame: 63 , param: 192.0
# 48 1/6 0.3125
#  27% 64/240 [00:40<01:38,  1.78it/s]animating frame: 64 , param: 0.21666666666666667
# animating frame: 64 , param: 195.0
# 48 1/6 0.3333333333333333
#  27% 65/240 [00:41<01:37,  1.79it/s]animating frame: 65 , param: 0.22
# animating frame: 65 , param: 198.0
# 48 1/6 0.3541666666666667
#  28% 66/240 [00:42<01:36,  1.80it/s]animating frame: 66 , param: 0.22333333333333336
# animating frame: 66 , param: 201.0
# 48 1/6 0.375
#  28% 67/240 [00:42<01:35,  1.81it/s]animating frame: 67 , param: 0.22666666666666668
# animating frame: 67 , param: 204.0
# 48 1/6 0.3958333333333333
#  28% 68/240 [00:43<01:35,  1.81it/s]animating frame: 68 , param: 0.23
# animating frame: 68 , param: 207.0
# 48 1/6 0.4166666666666667
#  29% 69/240 [00:43<01:33,  1.83it/s]animating frame: 69 , param: 0.23333333333333334
# animating frame: 69 , param: 210.0
# 48 1/6 0.4375
#  29% 70/240 [00:44<01:32,  1.84it/s]animating frame: 70 , param: 0.2366666666666667
# animating frame: 70 , param: 213.0
# 48 1/6 0.4583333333333333
#  30% 71/240 [00:44<01:31,  1.85it/s]animating frame: 71 , param: 0.24000000000000002
# animating frame: 71 , param: 216.0
# 48 1/6 0.4791666666666667
#  30% 72/240 [00:45<01:30,  1.86it/s]animating frame: 72 , param: 0.24333333333333335
# animating frame: 72 , param: 219.0
# 48 1/6 0.5
#  30% 73/240 [00:45<01:29,  1.87it/s]animating frame: 73 , param: 0.24666666666666667
# animating frame: 73 , param: 222.0
# 48 1/6 0.5208333333333334
#  31% 74/240 [00:46<01:28,  1.87it/s]animating frame: 74 , param: 0.25
# animating frame: 74 , param: 225.0
# 48 1/6 0.5416666666666666
#  31% 75/240 [00:46<01:27,  1.88it/s]animating frame: 75 , param: 0.25333333333333335
# animating frame: 75 , param: 228.0
# 48 1/6 0.5625
#  32% 76/240 [00:47<01:26,  1.89it/s]animating frame: 76 , param: 0.2566666666666667
# animating frame: 76 , param: 231.0
# 48 1/6 0.5833333333333334
#  32% 77/240 [00:47<01:25,  1.90it/s]animating frame: 77 , param: 0.26
# animating frame: 77 , param: 234.0
# 48 1/6 0.6041666666666666
#  32% 78/240 [00:48<01:24,  1.91it/s]animating frame: 78 , param: 0.26333333333333336
# animating frame: 78 , param: 237.0
# 48 1/6 0.625
#  33% 79/240 [00:48<01:23,  1.92it/s]animating frame: 79 , param: 0.26666666666666666
# animating frame: 79 , param: 240.0
# 48 1/6 0.6458333333333334
#  33% 80/240 [00:49<01:22,  1.94it/s]animating frame: 80 , param: 0.27
# animating frame: 80 , param: 243.0
# 48 1/6 0.6666666666666666
#  34% 81/240 [00:49<01:21,  1.95it/s]animating frame: 81 , param: 0.2733333333333334
# animating frame: 81 , param: 246.0
# 48 1/6 0.6875
#  34% 82/240 [00:50<01:20,  1.97it/s]animating frame: 82 , param: 0.27666666666666667
# animating frame: 82 , param: 249.0
# 48 1/6 0.7083333333333334
#  35% 83/240 [00:50<01:18,  1.99it/s]animating frame: 83 , param: 0.28
# animating frame: 83 , param: 252.0
# 48 1/6 0.7291666666666666
#  35% 84/240 [00:51<01:17,  2.00it/s]animating frame: 84 , param: 0.2833333333333333
# animating frame: 84 , param: 255.0
# 48 1/6 0.75
#  35% 85/240 [00:51<01:17,  2.01it/s]animating frame: 85 , param: 0.2866666666666667
# animating frame: 85 , param: 258.0
# 48 1/6 0.7708333333333334
#  36% 86/240 [00:52<01:16,  2.00it/s]animating frame: 86 , param: 0.29000000000000004
# animating frame: 86 , param: 261.0
# 48 1/6 0.7916666666666666
#  36% 87/240 [00:52<01:16,  2.00it/s]animating frame: 87 , param: 0.29333333333333333
# animating frame: 87 , param: 264.0
# 48 1/6 0.8125
#  37% 88/240 [00:53<01:17,  1.97it/s]animating frame: 88 , param: 0.2966666666666667
# animating frame: 88 , param: 267.0
# 48 1/6 0.8333333333333334
#  37% 89/240 [00:53<01:16,  1.98it/s]animating frame: 89 , param: 0.30000000000000004
# animating frame: 89 , param: 270.0
# 48 1/6 0.8541666666666666
#  38% 90/240 [00:54<01:15,  1.98it/s]animating frame: 90 , param: 0.30333333333333334
# animating frame: 90 , param: 273.0
# 48 1/6 0.875
#  38% 91/240 [00:54<01:14,  1.99it/s]animating frame: 91 , param: 0.3066666666666667
# animating frame: 91 , param: 276.0
# 48 1/6 0.8958333333333334
#  38% 92/240 [00:55<01:14,  1.99it/s]animating frame: 92 , param: 0.31
# animating frame: 92 , param: 279.0
# 48 1/6 0.9166666666666666
#  39% 93/240 [00:55<01:13,  2.00it/s]animating frame: 93 , param: 0.31333333333333335
# animating frame: 93 , param: 282.0
# 48 1/6 0.9375
#  39% 94/240 [00:56<01:12,  2.00it/s]animating frame: 94 , param: 0.3166666666666667
# animating frame: 94 , param: 285.0
# 48 1/6 0.9583333333333334
#  40% 95/240 [00:56<01:12,  1.99it/s]animating frame: 95 , param: 0.32
# animating frame: 95 , param: 288.0
# 48 1/6 0.9791666666666666
#  40% 96/240 [00:57<01:12,  1.99it/s]animating frame: 96 , param: 0.32333333333333336
# animating frame: 96 , param: 291.0
# 48 2/6 0.0
#  40% 97/240 [00:57<01:11,  2.00it/s]animating frame: 97 , param: 0.32666666666666666
# animating frame: 97 , param: 294.0
# 48 2/6 0.020833333333333332
#  41% 98/240 [00:58<01:10,  2.00it/s]animating frame: 98 , param: 0.33
# animating frame: 98 , param: 297.0
# 48 2/6 0.041666666666666664
#  41% 99/240 [00:58<01:10,  2.01it/s]animating frame: 99 , param: 0.33333333333333337
# animating frame: 99 , param: 300.0
# 48 2/6 0.0625
#  42% 100/240 [00:59<01:09,  2.00it/s]animating frame: 100 , param: 0.33666666666666667
# animating frame: 100 , param: 303.0
# 48 2/6 0.08333333333333333
#  42% 101/240 [00:59<01:09,  2.00it/s]animating frame: 101 , param: 0.34
# animating frame: 101 , param: 306.0
# 48 2/6 0.10416666666666667
#  42% 102/240 [01:00<01:09,  2.00it/s]animating frame: 102 , param: 0.3433333333333334
# animating frame: 102 , param: 309.0
# 48 2/6 0.125
#  43% 103/240 [01:00<01:08,  2.00it/s]animating frame: 103 , param: 0.3466666666666667
# animating frame: 103 , param: 312.0
# 48 2/6 0.14583333333333334
#  43% 104/240 [01:01<01:07,  2.01it/s]animating frame: 104 , param: 0.35000000000000003
# animating frame: 104 , param: 315.0
# 48 2/6 0.16666666666666666
#  44% 105/240 [01:01<01:07,  2.01it/s]animating frame: 105 , param: 0.35333333333333333
# animating frame: 105 , param: 318.0
# 48 2/6 0.1875
#  44% 106/240 [01:02<01:06,  2.01it/s]animating frame: 106 , param: 0.3566666666666667
# animating frame: 106 , param: 321.0
# 48 2/6 0.20833333333333334
#  45% 107/240 [01:02<01:06,  2.01it/s]animating frame: 107 , param: 0.36000000000000004
# animating frame: 107 , param: 324.0
# 48 2/6 0.22916666666666666
#  45% 108/240 [01:03<01:05,  2.00it/s]animating frame: 108 , param: 0.36333333333333334
# animating frame: 108 , param: 327.0
# 48 2/6 0.25
#  45% 109/240 [01:03<01:05,  2.01it/s]animating frame: 109 , param: 0.3666666666666667
# animating frame: 109 , param: 330.0
# 48 2/6 0.2708333333333333
#  46% 110/240 [01:04<01:04,  2.02it/s]animating frame: 110 , param: 0.37000000000000005
# animating frame: 110 , param: 333.0
# 48 2/6 0.2916666666666667
#  46% 111/240 [01:04<01:04,  2.01it/s]animating frame: 111 , param: 0.37333333333333335
# animating frame: 111 , param: 336.0
# 48 2/6 0.3125
#  47% 112/240 [01:05<01:03,  2.02it/s]animating frame: 112 , param: 0.3766666666666667
# animating frame: 112 , param: 339.0
# 48 2/6 0.3333333333333333
#  47% 113/240 [01:05<01:03,  2.01it/s]animating frame: 113 , param: 0.38
# animating frame: 113 , param: 342.0
# 48 2/6 0.3541666666666667
#  48% 114/240 [01:06<01:02,  2.01it/s]animating frame: 114 , param: 0.38333333333333336
# animating frame: 114 , param: 345.0
# 48 2/6 0.375
#  48% 115/240 [01:06<01:02,  2.00it/s]animating frame: 115 , param: 0.3866666666666667
# animating frame: 115 , param: 348.0
# 48 2/6 0.3958333333333333
#  48% 116/240 [01:07<01:02,  2.00it/s]animating frame: 116 , param: 0.39
# animating frame: 116 , param: 351.0
# 48 2/6 0.4166666666666667
#  49% 117/240 [01:07<01:02,  1.98it/s]animating frame: 117 , param: 0.39333333333333337
# animating frame: 117 , param: 354.0
# 48 2/6 0.4375
#  49% 118/240 [01:08<01:01,  1.97it/s]animating frame: 118 , param: 0.39666666666666667
# animating frame: 118 , param: 357.0
# 48 2/6 0.4583333333333333
#  50% 119/240 [01:08<01:01,  1.96it/s]animating frame: 119 , param: 0.4
# animating frame: 119 , param: 360.0
# 48 2/6 0.4791666666666667
#  50% 120/240 [01:09<01:01,  1.95it/s]animating frame: 120 , param: 0.4033333333333334
# animating frame: 120 , param: 363.0
# 48 2/6 0.5
# Rotation parameter should be a float between 0 and 360 degrees.
#  50% 121/240 [01:09<01:01,  1.93it/s]animating frame: 121 , param: 0.4066666666666667
# animating frame: 121 , param: 366.0
# 48 2/6 0.5208333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  51% 122/240 [01:10<01:01,  1.92it/s]animating frame: 122 , param: 0.41000000000000003
# animating frame: 122 , param: 369.0
# 48 2/6 0.5416666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  51% 123/240 [01:11<01:01,  1.92it/s]animating frame: 123 , param: 0.4133333333333334
# animating frame: 123 , param: 372.0
# 48 2/6 0.5625
# Rotation parameter should be a float between 0 and 360 degrees.
#  52% 124/240 [01:11<01:00,  1.91it/s]animating frame: 124 , param: 0.4166666666666667
# animating frame: 124 , param: 375.0
# 48 2/6 0.5833333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  52% 125/240 [01:12<01:00,  1.91it/s]animating frame: 125 , param: 0.42000000000000004
# animating frame: 125 , param: 378.0
# 48 2/6 0.6041666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  52% 126/240 [01:12<00:59,  1.91it/s]animating frame: 126 , param: 0.42333333333333334
# animating frame: 126 , param: 381.0
# 48 2/6 0.625
# Rotation parameter should be a float between 0 and 360 degrees.
#  53% 127/240 [01:13<00:59,  1.90it/s]animating frame: 127 , param: 0.4266666666666667
# animating frame: 127 , param: 384.0
# 48 2/6 0.6458333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  53% 128/240 [01:13<00:59,  1.89it/s]animating frame: 128 , param: 0.43000000000000005
# animating frame: 128 , param: 387.0
# 48 2/6 0.6666666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  54% 129/240 [01:14<00:58,  1.89it/s]animating frame: 129 , param: 0.43333333333333335
# animating frame: 129 , param: 390.0
# 48 2/6 0.6875
# Rotation parameter should be a float between 0 and 360 degrees.
#  54% 130/240 [01:14<00:58,  1.88it/s]animating frame: 130 , param: 0.4366666666666667
# animating frame: 130 , param: 393.0
# 48 2/6 0.7083333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  55% 131/240 [01:15<00:58,  1.88it/s]animating frame: 131 , param: 0.44
# animating frame: 131 , param: 396.0
# 48 2/6 0.7291666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  55% 132/240 [01:15<00:57,  1.86it/s]animating frame: 132 , param: 0.44333333333333336
# animating frame: 132 , param: 399.0
# 48 2/6 0.75
# Rotation parameter should be a float between 0 and 360 degrees.
#  55% 133/240 [01:16<00:57,  1.85it/s]animating frame: 133 , param: 0.4466666666666667
# animating frame: 133 , param: 402.0
# 48 2/6 0.7708333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  56% 134/240 [01:16<00:57,  1.85it/s]animating frame: 134 , param: 0.45
# animating frame: 134 , param: 405.0
# 48 2/6 0.7916666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  56% 135/240 [01:17<00:57,  1.84it/s]animating frame: 135 , param: 0.45333333333333337
# animating frame: 135 , param: 408.0
# 48 2/6 0.8125
# Rotation parameter should be a float between 0 and 360 degrees.
#  57% 136/240 [01:18<00:56,  1.84it/s]animating frame: 136 , param: 0.4566666666666667
# animating frame: 136 , param: 411.0
# 48 2/6 0.8333333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  57% 137/240 [01:18<00:56,  1.83it/s]animating frame: 137 , param: 0.46
# animating frame: 137 , param: 414.0
# 48 2/6 0.8541666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  57% 138/240 [01:19<00:55,  1.83it/s]animating frame: 138 , param: 0.4633333333333334
# animating frame: 138 , param: 417.0
# 48 2/6 0.875
# Rotation parameter should be a float between 0 and 360 degrees.
#  58% 139/240 [01:19<00:55,  1.82it/s]animating frame: 139 , param: 0.4666666666666667
# animating frame: 139 , param: 420.0
# 48 2/6 0.8958333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  58% 140/240 [01:20<00:54,  1.82it/s]animating frame: 140 , param: 0.47000000000000003
# animating frame: 140 , param: 423.0
# 48 2/6 0.9166666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  59% 141/240 [01:20<00:54,  1.81it/s]animating frame: 141 , param: 0.4733333333333334
# animating frame: 141 , param: 426.0
# 48 2/6 0.9375
# Rotation parameter should be a float between 0 and 360 degrees.
#  59% 142/240 [01:21<00:54,  1.81it/s]animating frame: 142 , param: 0.4766666666666667
# animating frame: 142 , param: 429.0
# 48 2/6 0.9583333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  60% 143/240 [01:21<00:53,  1.81it/s]animating frame: 143 , param: 0.48000000000000004
# animating frame: 143 , param: 432.0
# 48 2/6 0.9791666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  60% 144/240 [01:22<00:53,  1.80it/s]animating frame: 144 , param: 0.48333333333333334
# animating frame: 144 , param: 435.0
# 48 3/6 0.0
# Rotation parameter should be a float between 0 and 360 degrees.
#  60% 145/240 [01:23<00:53,  1.78it/s]animating frame: 145 , param: 0.4866666666666667
# animating frame: 145 , param: 438.0
# 48 3/6 0.020833333333333332
# Rotation parameter should be a float between 0 and 360 degrees.
#  61% 146/240 [01:23<00:52,  1.78it/s]animating frame: 146 , param: 0.49000000000000005
# animating frame: 146 , param: 441.0
# 48 3/6 0.041666666666666664
# Rotation parameter should be a float between 0 and 360 degrees.
#  61% 147/240 [01:24<00:52,  1.77it/s]animating frame: 147 , param: 0.49333333333333335
# animating frame: 147 , param: 444.0
# 48 3/6 0.0625
# Rotation parameter should be a float between 0 and 360 degrees.
#  62% 148/240 [01:24<00:52,  1.76it/s]animating frame: 148 , param: 0.4966666666666667
# animating frame: 148 , param: 447.0
# 48 3/6 0.08333333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  62% 149/240 [01:25<00:51,  1.75it/s]animating frame: 149 , param: 0.5
# animating frame: 149 , param: 450.0
# 48 3/6 0.10416666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  62% 150/240 [01:25<00:51,  1.74it/s]animating frame: 150 , param: 0.5033333333333334
# animating frame: 150 , param: 453.0
# 48 3/6 0.125
# Rotation parameter should be a float between 0 and 360 degrees.
#  63% 151/240 [01:26<00:52,  1.71it/s]animating frame: 151 , param: 0.5066666666666667
# animating frame: 151 , param: 456.0
# 48 3/6 0.14583333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  63% 152/240 [01:27<00:51,  1.71it/s]animating frame: 152 , param: 0.51
# animating frame: 152 , param: 459.0
# 48 3/6 0.16666666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  64% 153/240 [01:27<00:51,  1.70it/s]animating frame: 153 , param: 0.5133333333333334
# animating frame: 153 , param: 462.0
# 48 3/6 0.1875
# Rotation parameter should be a float between 0 and 360 degrees.
#  64% 154/240 [01:28<00:50,  1.69it/s]animating frame: 154 , param: 0.5166666666666667
# animating frame: 154 , param: 465.0
# 48 3/6 0.20833333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  65% 155/240 [01:28<00:50,  1.68it/s]animating frame: 155 , param: 0.52
# animating frame: 155 , param: 468.0
# 48 3/6 0.22916666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  65% 156/240 [01:29<00:50,  1.67it/s]animating frame: 156 , param: 0.5233333333333333
# animating frame: 156 , param: 471.0
# 48 3/6 0.25
# Rotation parameter should be a float between 0 and 360 degrees.
#  65% 157/240 [01:30<00:49,  1.66it/s]animating frame: 157 , param: 0.5266666666666667
# animating frame: 157 , param: 474.0
# 48 3/6 0.2708333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  66% 158/240 [01:30<00:49,  1.66it/s]animating frame: 158 , param: 0.53
# animating frame: 158 , param: 477.0
# 48 3/6 0.2916666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  66% 159/240 [01:31<00:49,  1.65it/s]animating frame: 159 , param: 0.5333333333333333
# animating frame: 159 , param: 480.0
# 48 3/6 0.3125
# Rotation parameter should be a float between 0 and 360 degrees.
#  67% 160/240 [01:31<00:48,  1.64it/s]animating frame: 160 , param: 0.5366666666666667
# animating frame: 160 , param: 483.0
# 48 3/6 0.3333333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  67% 161/240 [01:32<00:48,  1.64it/s]animating frame: 161 , param: 0.54
# animating frame: 161 , param: 486.0
# 48 3/6 0.3541666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  68% 162/240 [01:33<00:47,  1.63it/s]animating frame: 162 , param: 0.5433333333333333
# animating frame: 162 , param: 489.0
# 48 3/6 0.375
# Rotation parameter should be a float between 0 and 360 degrees.
#  68% 163/240 [01:33<00:47,  1.62it/s]animating frame: 163 , param: 0.5466666666666667
# animating frame: 163 , param: 492.0
# 48 3/6 0.3958333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  68% 164/240 [01:34<00:47,  1.62it/s]animating frame: 164 , param: 0.55
# animating frame: 164 , param: 495.0
# 48 3/6 0.4166666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  69% 165/240 [01:35<00:46,  1.61it/s]animating frame: 165 , param: 0.5533333333333333
# animating frame: 165 , param: 498.0
# 48 3/6 0.4375
# Rotation parameter should be a float between 0 and 360 degrees.
#  69% 166/240 [01:35<00:45,  1.62it/s]animating frame: 166 , param: 0.5566666666666668
# animating frame: 166 , param: 501.0
# 48 3/6 0.4583333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  70% 167/240 [01:36<00:44,  1.62it/s]animating frame: 167 , param: 0.56
# animating frame: 167 , param: 504.0
# 48 3/6 0.4791666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  70% 168/240 [01:36<00:44,  1.63it/s]animating frame: 168 , param: 0.5633333333333334
# animating frame: 168 , param: 507.0
# 48 3/6 0.5
# Rotation parameter should be a float between 0 and 360 degrees.
#  70% 169/240 [01:37<00:43,  1.64it/s]animating frame: 169 , param: 0.5666666666666667
# animating frame: 169 , param: 510.0
# 48 3/6 0.5208333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  71% 170/240 [01:38<00:42,  1.63it/s]animating frame: 170 , param: 0.5700000000000001
# animating frame: 170 , param: 513.0
# 48 3/6 0.5416666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  71% 171/240 [01:38<00:41,  1.65it/s]animating frame: 171 , param: 0.5733333333333334
# animating frame: 171 , param: 516.0
# 48 3/6 0.5625
# Rotation parameter should be a float between 0 and 360 degrees.
#  72% 172/240 [01:39<00:40,  1.66it/s]animating frame: 172 , param: 0.5766666666666667
# animating frame: 172 , param: 519.0
# 48 3/6 0.5833333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  72% 173/240 [01:39<00:40,  1.67it/s]animating frame: 173 , param: 0.5800000000000001
# animating frame: 173 , param: 522.0
# 48 3/6 0.6041666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  72% 174/240 [01:40<00:39,  1.67it/s]animating frame: 174 , param: 0.5833333333333334
# animating frame: 174 , param: 525.0
# 48 3/6 0.625
# Rotation parameter should be a float between 0 and 360 degrees.
#  73% 175/240 [01:41<00:38,  1.67it/s]animating frame: 175 , param: 0.5866666666666667
# animating frame: 175 , param: 528.0
# 48 3/6 0.6458333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  73% 176/240 [01:41<00:38,  1.68it/s]animating frame: 176 , param: 0.5900000000000001
# animating frame: 176 , param: 531.0
# 48 3/6 0.6666666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  74% 177/240 [01:42<00:37,  1.68it/s]animating frame: 177 , param: 0.5933333333333334
# animating frame: 177 , param: 534.0
# 48 3/6 0.6875
# Rotation parameter should be a float between 0 and 360 degrees.
#  74% 178/240 [01:42<00:36,  1.68it/s]animating frame: 178 , param: 0.5966666666666667
# animating frame: 178 , param: 537.0
# 48 3/6 0.7083333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  75% 179/240 [01:43<00:36,  1.68it/s]animating frame: 179 , param: 0.6000000000000001
# animating frame: 179 , param: 540.0
# 48 3/6 0.7291666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  75% 180/240 [01:44<00:35,  1.68it/s]animating frame: 180 , param: 0.6033333333333334
# animating frame: 180 , param: 543.0
# 48 3/6 0.75
# Rotation parameter should be a float between 0 and 360 degrees.
#  75% 181/240 [01:44<00:35,  1.68it/s]animating frame: 181 , param: 0.6066666666666667
# animating frame: 181 , param: 546.0
# 48 3/6 0.7708333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  76% 182/240 [01:45<00:34,  1.67it/s]animating frame: 182 , param: 0.61
# animating frame: 182 , param: 549.0
# 48 3/6 0.7916666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  76% 183/240 [01:45<00:34,  1.67it/s]animating frame: 183 , param: 0.6133333333333334
# animating frame: 183 , param: 552.0
# 48 3/6 0.8125
# Rotation parameter should be a float between 0 and 360 degrees.
#  77% 184/240 [01:46<00:33,  1.66it/s]animating frame: 184 , param: 0.6166666666666667
# animating frame: 184 , param: 555.0
# 48 3/6 0.8333333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  77% 185/240 [01:47<00:33,  1.66it/s]animating frame: 185 , param: 0.62
# animating frame: 185 , param: 558.0
# 48 3/6 0.8541666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  78% 186/240 [01:47<00:32,  1.67it/s]animating frame: 186 , param: 0.6233333333333334
# animating frame: 186 , param: 561.0
# 48 3/6 0.875
# Rotation parameter should be a float between 0 and 360 degrees.
#  78% 187/240 [01:48<00:31,  1.68it/s]animating frame: 187 , param: 0.6266666666666667
# animating frame: 187 , param: 564.0
# 48 3/6 0.8958333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  78% 188/240 [01:48<00:30,  1.69it/s]animating frame: 188 , param: 0.63
# animating frame: 188 , param: 567.0
# 48 3/6 0.9166666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  79% 189/240 [01:49<00:29,  1.70it/s]animating frame: 189 , param: 0.6333333333333334
# animating frame: 189 , param: 570.0
# 48 3/6 0.9375
# Rotation parameter should be a float between 0 and 360 degrees.
#  79% 190/240 [01:49<00:29,  1.72it/s]animating frame: 190 , param: 0.6366666666666667
# animating frame: 190 , param: 573.0
# 48 3/6 0.9583333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  80% 191/240 [01:50<00:28,  1.73it/s]animating frame: 191 , param: 0.64
# animating frame: 191 , param: 576.0
# 48 3/6 0.9791666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  80% 192/240 [01:51<00:27,  1.74it/s]animating frame: 192 , param: 0.6433333333333334
# animating frame: 192 , param: 579.0
# 48 4/6 0.0
# Rotation parameter should be a float between 0 and 360 degrees.
#  80% 193/240 [01:51<00:26,  1.74it/s]animating frame: 193 , param: 0.6466666666666667
# animating frame: 193 , param: 582.0
# 48 4/6 0.020833333333333332
# Rotation parameter should be a float between 0 and 360 degrees.
#  81% 194/240 [01:52<00:26,  1.74it/s]animating frame: 194 , param: 0.65
# animating frame: 194 , param: 585.0
# 48 4/6 0.041666666666666664
# Rotation parameter should be a float between 0 and 360 degrees.
#  81% 195/240 [01:52<00:25,  1.73it/s]animating frame: 195 , param: 0.6533333333333333
# animating frame: 195 , param: 588.0
# 48 4/6 0.0625
# Rotation parameter should be a float between 0 and 360 degrees.
#  82% 196/240 [01:53<00:25,  1.72it/s]animating frame: 196 , param: 0.6566666666666667
# animating frame: 196 , param: 591.0
# 48 4/6 0.08333333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  82% 197/240 [01:54<00:25,  1.71it/s]animating frame: 197 , param: 0.66
# animating frame: 197 , param: 594.0
# 48 4/6 0.10416666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  82% 198/240 [01:54<00:24,  1.69it/s]animating frame: 198 , param: 0.6633333333333333
# animating frame: 198 , param: 597.0
# 48 4/6 0.125
# Rotation parameter should be a float between 0 and 360 degrees.
#  83% 199/240 [01:55<00:24,  1.68it/s]animating frame: 199 , param: 0.6666666666666667
# animating frame: 199 , param: 600.0
# 48 4/6 0.14583333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  83% 200/240 [01:55<00:23,  1.68it/s]animating frame: 200 , param: 0.67
# animating frame: 200 , param: 603.0
# 48 4/6 0.16666666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  84% 201/240 [01:56<00:23,  1.67it/s]animating frame: 201 , param: 0.6733333333333333
# animating frame: 201 , param: 606.0
# 48 4/6 0.1875
# Rotation parameter should be a float between 0 and 360 degrees.
#  84% 202/240 [01:57<00:22,  1.67it/s]animating frame: 202 , param: 0.6766666666666667
# animating frame: 202 , param: 609.0
# 48 4/6 0.20833333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  85% 203/240 [01:57<00:22,  1.66it/s]animating frame: 203 , param: 0.68
# animating frame: 203 , param: 612.0
# 48 4/6 0.22916666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  85% 204/240 [01:58<00:21,  1.65it/s]animating frame: 204 , param: 0.6833333333333333
# animating frame: 204 , param: 615.0
# 48 4/6 0.25
# Rotation parameter should be a float between 0 and 360 degrees.
#  85% 205/240 [01:58<00:21,  1.64it/s]animating frame: 205 , param: 0.6866666666666668
# animating frame: 205 , param: 618.0
# 48 4/6 0.2708333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  86% 206/240 [01:59<00:21,  1.61it/s]animating frame: 206 , param: 0.6900000000000001
# animating frame: 206 , param: 621.0
# 48 4/6 0.2916666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  86% 207/240 [02:00<00:20,  1.60it/s]animating frame: 207 , param: 0.6933333333333334
# animating frame: 207 , param: 624.0
# 48 4/6 0.3125
# Rotation parameter should be a float between 0 and 360 degrees.
#  87% 208/240 [02:00<00:20,  1.60it/s]animating frame: 208 , param: 0.6966666666666667
# animating frame: 208 , param: 627.0
# 48 4/6 0.3333333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  87% 209/240 [02:01<00:19,  1.59it/s]animating frame: 209 , param: 0.7000000000000001
# animating frame: 209 , param: 630.0
# 48 4/6 0.3541666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  88% 210/240 [02:02<00:18,  1.59it/s]animating frame: 210 , param: 0.7033333333333334
# animating frame: 210 , param: 633.0
# 48 4/6 0.375
# Rotation parameter should be a float between 0 and 360 degrees.
#  88% 211/240 [02:02<00:18,  1.60it/s]animating frame: 211 , param: 0.7066666666666667
# animating frame: 211 , param: 636.0
# 48 4/6 0.3958333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  88% 212/240 [02:03<00:17,  1.61it/s]animating frame: 212 , param: 0.7100000000000001
# animating frame: 212 , param: 639.0
# 48 4/6 0.4166666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  89% 213/240 [02:03<00:16,  1.62it/s]animating frame: 213 , param: 0.7133333333333334
# animating frame: 213 , param: 642.0
# 48 4/6 0.4375
# Rotation parameter should be a float between 0 and 360 degrees.
#  89% 214/240 [02:04<00:15,  1.64it/s]animating frame: 214 , param: 0.7166666666666667
# animating frame: 214 , param: 645.0
# 48 4/6 0.4583333333333333
# Rotation parameter should be a float between 0 and 360 degrees.
#  90% 215/240 [02:05<00:15,  1.65it/s]animating frame: 215 , param: 0.7200000000000001
# animating frame: 215 , param: 648.0
# 48 4/6 0.4791666666666667
# Rotation parameter should be a float between 0 and 360 degrees.
#  90% 216/240 [02:05<00:14,  1.67it/s]animating frame: 216 , param: 0.7233333333333334
# animating frame: 216 , param: 651.0
# 48 4/6 0.5
# Rotation parameter should be a float between 0 and 360 degrees.
#  90% 217/240 [02:06<00:13,  1.69it/s]animating frame: 217 , param: 0.7266666666666667
# animating frame: 217 , param: 654.0
# 48 4/6 0.5208333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  91% 218/240 [02:06<00:12,  1.71it/s]animating frame: 218 , param: 0.7300000000000001
# animating frame: 218 , param: 657.0
# 48 4/6 0.5416666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  91% 219/240 [02:07<00:12,  1.72it/s]animating frame: 219 , param: 0.7333333333333334
# animating frame: 219 , param: 660.0
# 48 4/6 0.5625
# Rotation parameter should be a float between 0 and 360 degrees.
#  92% 220/240 [02:07<00:11,  1.74it/s]animating frame: 220 , param: 0.7366666666666667
# animating frame: 220 , param: 663.0
# 48 4/6 0.5833333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  92% 221/240 [02:08<00:10,  1.75it/s]animating frame: 221 , param: 0.7400000000000001
# animating frame: 221 , param: 666.0
# 48 4/6 0.6041666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  92% 222/240 [02:09<00:10,  1.77it/s]animating frame: 222 , param: 0.7433333333333334
# animating frame: 222 , param: 669.0
# 48 4/6 0.625
# Rotation parameter should be a float between 0 and 360 degrees.
#  93% 223/240 [02:09<00:09,  1.79it/s]animating frame: 223 , param: 0.7466666666666667
# animating frame: 223 , param: 672.0
# 48 4/6 0.6458333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  93% 224/240 [02:10<00:08,  1.80it/s]animating frame: 224 , param: 0.75
# animating frame: 224 , param: 675.0
# 48 4/6 0.6666666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  94% 225/240 [02:10<00:08,  1.83it/s]animating frame: 225 , param: 0.7533333333333334
# animating frame: 225 , param: 678.0
# 48 4/6 0.6875
# Rotation parameter should be a float between 0 and 360 degrees.
#  94% 226/240 [02:11<00:07,  1.86it/s]animating frame: 226 , param: 0.7566666666666667
# animating frame: 226 , param: 681.0
# 48 4/6 0.7083333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  95% 227/240 [02:11<00:06,  1.88it/s]animating frame: 227 , param: 0.76
# animating frame: 227 , param: 684.0
# 48 4/6 0.7291666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  95% 228/240 [02:12<00:06,  1.92it/s]animating frame: 228 , param: 0.7633333333333334
# animating frame: 228 , param: 687.0
# 48 4/6 0.75
# Rotation parameter should be a float between 0 and 360 degrees.
#  95% 229/240 [02:12<00:05,  1.95it/s]animating frame: 229 , param: 0.7666666666666667
# animating frame: 229 , param: 690.0
# 48 4/6 0.7708333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  96% 230/240 [02:13<00:05,  1.99it/s]animating frame: 230 , param: 0.77
# animating frame: 230 , param: 693.0
# 48 4/6 0.7916666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  96% 231/240 [02:13<00:04,  2.02it/s]animating frame: 231 , param: 0.7733333333333334
# animating frame: 231 , param: 696.0
# 48 4/6 0.8125
# Rotation parameter should be a float between 0 and 360 degrees.
#  97% 232/240 [02:14<00:03,  2.04it/s]animating frame: 232 , param: 0.7766666666666667
# animating frame: 232 , param: 699.0
# 48 4/6 0.8333333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  97% 233/240 [02:14<00:03,  2.05it/s]animating frame: 233 , param: 0.78
# animating frame: 233 , param: 702.0
# 48 4/6 0.8541666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  98% 234/240 [02:15<00:02,  2.07it/s]animating frame: 234 , param: 0.7833333333333334
# animating frame: 234 , param: 705.0
# 48 4/6 0.875
# Rotation parameter should be a float between 0 and 360 degrees.
#  98% 235/240 [02:15<00:02,  2.09it/s]animating frame: 235 , param: 0.7866666666666667
# animating frame: 235 , param: 708.0
# 48 4/6 0.8958333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
#  98% 236/240 [02:16<00:01,  2.12it/s]animating frame: 236 , param: 0.79
# animating frame: 236 , param: 711.0
# 48 4/6 0.9166666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
#  99% 237/240 [02:16<00:01,  2.13it/s]animating frame: 237 , param: 0.7933333333333333
# animating frame: 237 , param: 714.0
# 48 4/6 0.9375
# Rotation parameter should be a float between 0 and 360 degrees.
#  99% 238/240 [02:16<00:00,  2.15it/s]animating frame: 238 , param: 0.7966666666666667
# animating frame: 238 , param: 717.0
# 48 4/6 0.9583333333333334
# Rotation parameter should be a float between 0 and 360 degrees.
# 100% 239/240 [02:17<00:00,  2.17it/s]animating frame: 239 , param: 0.8
# animating frame: 239 , param: 720.0
# 48 4/6 0.9791666666666666
# Rotation parameter should be a float between 0 and 360 degrees.
# 100% 240/240 [02:17<00:00,  1.74it/s]
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'ladiesblack-multi-test-noise2/frame%06d.png':
#   Duration: 00:00:09.60, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f301b17e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x55f301b17e00] profile High, level 3.2
# [libx264 @ 0x55f301b17e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'ladiesblack-multi-test-noise2/bend.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  240 fps= 17 q=-1.0 Lsize=    3053kB time=00:00:09.87 bitrate=2533.1kbits/s speed= 0.7x
# video:3050kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.102062%
# [libx264 @ 0x55f301b17e00] frame I:1     Avg QP:24.51  size: 98055
# [libx264 @ 0x55f301b17e00] frame P:120   Avg QP:20.17  size: 18056
# [libx264 @ 0x55f301b17e00] frame B:119   Avg QP:25.72  size:  7211
# [libx264 @ 0x55f301b17e00] consecutive B-frames: 32.5%  4.2%  0.0% 63.3%
# [libx264 @ 0x55f301b17e00] mb I  I16..4:  5.0% 68.0% 27.0%
# [libx264 @ 0x55f301b17e00] mb P  I16..4:  0.6%  4.8%  1.8%  P16..4: 19.5%  4.8%  4.5%  0.0%  0.0%    skip:64.0%
# [libx264 @ 0x55f301b17e00] mb B  I16..4:  0.0%  0.3%  0.2%  B16..8: 15.3%  1.7%  1.1%  direct: 7.0%  skip:74.4%  L0:36.3% L1:55.4% BI: 8.2%
# [libx264 @ 0x55f301b17e00] 8x8 transform intra:66.4% inter:67.2%
# [libx264 @ 0x55f301b17e00] coded y,uvDC,uvAC intra: 77.9% 46.0% 25.1% inter: 11.3% 7.9% 0.2%
# [libx264 @ 0x55f301b17e00] i16 v,h,dc,p: 34% 16% 38% 11%
# [libx264 @ 0x55f301b17e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27%  4% 28%  8%  3%  7%  3% 16%  5%
# [libx264 @ 0x55f301b17e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30%  5% 18% 10%  5%  8%  4% 15%  5%
# [libx264 @ 0x55f301b17e00] i8c dc,h,v,p: 67%  7% 21%  5%
# [libx264 @ 0x55f301b17e00] Weighted P-Frames: Y:7.5% UV:4.2%
# [libx264 @ 0x55f301b17e00] ref P L0: 74.5% 11.9%  9.8%  3.5%  0.4%
# [libx264 @ 0x55f301b17e00] ref B L0: 89.9%  7.9%  2.2%
# [libx264 @ 0x55f301b17e00] ref B L1: 93.9%  6.1%
# [libx264 @ 0x55f301b17e00] kb/s:2498.32

# %% [markdown]
# ## Generate Clusters
#
# More TK on this section because honestly I’m not sure this is all that’s needed.

# %%
# !python get_clusters.py --ckpt /content/network-bending/FreaGAN-10k.pt

# %% [markdown]
# ##Handmade stuff

# %%
import os
import copy
import torch
import yaml

from torchvision import utils
from model import Generator
from tqdm import tqdm
from util import *

frames = 120

# https://discuss.pytorch.org/t/help-regarding-slerp-function-for-generative-model-sampling/32475/4
def slerp(val, low, high):
    low_norm = low/torch.norm(low, dim=1, keepdim=True)
    high_norm = high/torch.norm(high, dim=1, keepdim=True)
    omega = torch.acos((low_norm*high_norm).sum(1))
    so = torch.sin(omega)
    res = (torch.sin((1.0-val)*omega)/so).unsqueeze(1)*low + (torch.sin(val*omega)/so).unsqueeze(1) * high
    print(res.shape)
    return res

device = "cuda"
g_ema = Generator(
        1024, 512, 8, 2
    ).to(device)
checkpoint = torch.load('/content/ladiesblack.pt')
g_ema.load_state_dict(checkpoint["g_ema"])

with torch.no_grad():
    mean_latent = g_ema.mean_latent(4096)

yaml_config = {}
with open('/content/network-bending/configs/empty_transform_config.yaml', 'r') as stream:
    try:
        yaml_config = yaml.load(stream)
    except yaml.YAMLError as exc:
        print(exc)

cluster_config = {}
layer_channel_dims = create_layer_channel_dim_dict(2)

# create noise
noise = [getattr(g_ema.noises, f"noise_{i}") for i in range(g_ema.num_layers)]

noise2 = copy.deepcopy(noise)
for i,n in enumerate(noise2):
    if len(n[0][0]) < 256:
        # print('update: ', n.shape)
        noise2[i] = (0.1**0.5)*torch.randn_like(n)

# only slerp for lower layers, keep defaults for higher layers (won't fit in VRAM)
# noise_slerps = []
# for f in range(int(frames/2)):
#     ns = []
#     for i in range(len(noise)):
#         if len(noise[i][0][0]) < 256:
#             # print('update: ', noise[i].shape)
#             ns.append(slerp(f/(frames/2), noise[i], noise2[i]))
#     noise_slerps.append(ns)

noise_slerps = []
for f in range(int(frames/2)):
    ns = []
    for i in range(len(noise)):
        # if len(noise[i][0][0]) < 256:
            # print('update: ', noise[i].shape)
        #ns.append(slerp((f/(frames/2)), noise[i], noise2[i]))
        ns.append( torch.lerp( noise[i], noise2[i], (f/(frames/2)) ) )
    noise_slerps.append(ns)

#print(len(noise_slerps))

with torch.no_grad():
    g_ema.eval()
    t_dict_list = create_transforms_dict_list(yaml_config, cluster_config, layer_channel_dims)
    
    sample_z = torch.randn(1, 512, device=device)
    for i in tqdm(range(len(noise_slerps))):
        
        sample, _ = g_ema([sample_z], truncation=0.7, noise=noise_slerps[i], truncation_latent=mean_latent, transform_dict_list=t_dict_list)
        #sample2, _ = g_ema([sample_z], truncation=0.7, noise=noise, truncation_latent=mean_latent, transform_dict_list=t_dict_list)

        if not os.path.exists('interpolations'):
            os.makedirs('interpolations')

        utils.save_image(
            sample,
            f'interpolations/{str(i).zfill(6)}.png',
            nrow=1,
            normalize=True,
            range=(-1, 1))
# Out:
# 100%|██████████| 60/60 [00:29<00:00,  2.04it/s]

# %%
# !ffmpeg -r 24 -i /content/network-bending/interpolations/%06d.png -vcodec libx264 -pix_fmt yuv420p noise-test.mp4 -y

# %% [markdown]
# ## Helper functions

# %%
rm -rf /content/network-bending/sample-animation/frame*.png

# %%
# !gdown --id 1rL-J63eFfn80IYU2GfVY977GI2qOG6dw -O /content/ladiesblack.pt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1rL-J63eFfn80IYU2GfVY977GI2qOG6dw
# To: /content/ladiesblack.pt
# 133MB [00:01, 103MB/s]
